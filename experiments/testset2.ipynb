# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoImageProcessor, Dinov2Model
from PIL import Image
from pathlib import Path
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.neighbors import KNeighborsClassifier
import argparse
import tarfile
import urllib.request
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from PIL import Image
from torch.utils.data import Dataset, Subset
from torchvision.transforms import v2

# %%
# def collate_fn(batch):
#     """Custom collate function to handle PIL images"""
#     if len(batch[0]) == 3:  # train/val (image, label, filename)
#         images = [item[0] for item in batch]
#         labels = [item[1] for item in batch]
#         filenames = [item[2] for item in batch]
#         return images, labels, filenames
#     else:  # test (image, filename)
#         images = [item[0] for item in batch]
#         filenames = [item[1] for item in batch]
#         return images, filenames

# %%
# class ImageDataset(Dataset):
#     def __init__(self, image_dir, image_list, labels=None,
#                  resolution=224, split="train", apply_transforms=True):
#         self.image_dir = Path(image_dir)
#         self.image_list = image_list
#         self.labels = labels
#         self.split = split
#         self.resolution = resolution
#         self.apply_transforms = apply_transforms

#         imagenet_mean = [0.485, 0.456, 0.406]
#         imagenet_std = [0.229, 0.224, 0.225]

#         if apply_transforms:
#             if split == "train":
#                 self.transform = v2.Compose([
#                     v2.RandomResizedCrop(resolution, scale=(0.8, 1.0)),
#                     v2.RandomHorizontalFlip(p=0.5),
#                     v2.ColorJitter(
#                         brightness=0.4,
#                         contrast=0.4,
#                         saturation=0.4,
#                         hue=0.1
#                     ),
#                     v2.ToImage(),
#                     v2.ToDtype(torch.float32, scale=True),
#                     v2.Normalize(mean=imagenet_mean, std=imagenet_std),
#                 ])
#             else:
#                 self.transform = v2.Compose([
#                     v2.Resize(256),
#                     v2.CenterCrop(resolution),
#                     v2.ToImage(),
#                     v2.ToDtype(torch.float32, scale=True),
#                     v2.Normalize(mean=imagenet_mean, std=imagenet_std),
#                 ])
#         else:
#             self.transform = None   # <-- important

#     def __len__(self):
#         return len(self.image_list)

#     def __getitem__(self, idx):
#         img_name = self.image_list[idx]
#         img_path = self.image_dir / img_name

#         img = Image.open(img_path).convert('RGB')

#         if self.transform is not None:
#             img = self.transform(img)   # -> Tensor (for supervised)
#         # else: keep img as PIL (for SSL)

#         if self.labels is not None:
#             return img, self.labels[idx], img_name
#         return img, img_name



class ImageDataset(Dataset):
    def __init__(self, image_dir, image_list, labels=None,
                 resolution=224, split="train", apply_transforms=True):
        self.image_dir = Path(image_dir)
        self.image_list = image_list
        self.labels = labels
        self.split = split
        self.resolution = resolution
        self.apply_transforms = apply_transforms

        imagenet_mean = [0.485, 0.456, 0.406]
        imagenet_std = [0.229, 0.224, 0.225]

        if apply_transforms:
            if split == "train":
                self.transform = v2.Compose([
                    v2.RandomResizedCrop(resolution, scale=(0.8, 1.0)),
                    v2.RandomHorizontalFlip(p=0.5),
                    v2.ColorJitter(
                        brightness=0.4,
                        contrast=0.4,
                        saturation=0.4,
                        hue=0.1
                    ),
                    v2.ToImage(),
                    v2.ToDtype(torch.float32, scale=True),
                    v2.Normalize(mean=imagenet_mean, std=imagenet_std),
                ])
            else:
                self.transform = v2.Compose([
                    v2.Resize(256),
                    v2.CenterCrop(resolution),
                    v2.ToImage(),
                    v2.ToDtype(torch.float32, scale=True),
                    v2.Normalize(mean=imagenet_mean, std=imagenet_std),
                ])
        else:
            self.transform = None

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        img_name = self.image_list[idx]
        img_path = self.image_dir / img_name

        img = Image.open(img_path).convert('RGB')

        if self.transform is not None:
            img = self.transform(img)

        if self.labels is not None:
            if self.split == "test":
                # For test: return (img, label, idx) so we can align with test_df
                return img, self.labels[idx], idx
            else:
                # For train/val: keep old behavior (img, label, img_name)
                return img, self.labels[idx], img_name

        # Unlabeled case (e.g., SSL)
        if self.split == "test":
            return img, idx
        else:
            return img, img_name

# %%
from pathlib import Path
import pandas as pd
from torch.utils.data import DataLoader

# ============================================================
# Hyperparameters (replace args.*)
# ============================================================
batch_size = 64
num_workers = 4
resolution = 224   # or whatever you want for training
# ============================================================

# Load CSV files
data_dir = Path("/home/long/code/amogh/data/testset_3")

print("\nLoading dataset metadata...")
train_df = pd.read_csv(data_dir / 'train_labels.csv')
val_df = pd.read_csv(data_dir / 'val_labels.csv')
test_df = pd.read_csv(data_dir / 'test_labels_INTERNAL.csv')

print(f"  Train: {len(train_df)} images")
print(f"  Val:   {len(val_df)} images")
print(f"  Test:  {len(test_df)} images")
print(f"  Classes: {train_df['class_id'].nunique()}")

train_dataset1 = ImageDataset(
    data_dir / 'train',
    train_df['filename'].tolist(),
    train_df['class_id'].tolist(),
    resolution=resolution,
    apply_transforms=True,
)

val_dataset1 = ImageDataset(
    data_dir / 'val',
    val_df['filename'].tolist(),
    val_df['class_id'].tolist(),
    resolution=resolution,
    apply_transforms=True,
)

test_dataset1 = ImageDataset(
    data_dir / 'test',
    test_df['filename'].tolist(),
    labels=test_df['class_id'].tolist(),
    resolution=resolution,
    apply_transforms=True,
    split="test"
)

train_loader1 = DataLoader(
    train_dataset1,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    # collate_fn=collate_fn,
)

val_loader1 = DataLoader(
    val_dataset1,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    # collate_fn=collate_fn,
)

test_loader1 = DataLoader(
    test_dataset1,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    # collate_fn=collate_fn,
)
# Out:
# Loading dataset metadata...
#   Train: 13895 images
#   Val:   2977 images
#   Test:  2978 images
#   Classes: 397

# %%
#load the model

# %%
import tarfile
import urllib.request
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from PIL import Image
from torch.utils.data import Dataset, Subset
from torchvision.transforms import v2

# %%
import torch
import torchvision
from timm.models.vision_transformer import vit_base_patch32_224
from torch import nn
from lightly.models import utils
from lightly.models.modules import MAEDecoderTIMM, MaskedVisionTransformerTIMM
from lightly.transforms import MAETransform
import copy
from lightly.models.modules import DINOProjectionHead
from lightly.loss import DINOLoss  # only needed if you re-train SSL
from lightly.models.utils import deactivate_requires_grad

# %%
class DINO(nn.Module):
    def __init__(self, backbone, input_dim):
        super().__init__()
        self.student_backbone = backbone
        self.student_head = DINOProjectionHead(
            input_dim, 512, 64, 2048, freeze_last_layer=1
        )
        self.teacher_backbone = copy.deepcopy(backbone)
        self.teacher_head = DINOProjectionHead(input_dim, 512, 64, 2048)
        deactivate_requires_grad(self.teacher_backbone)
        deactivate_requires_grad(self.teacher_head)

    def forward(self, x):
        y = self.student_backbone(x).flatten(start_dim=1)
        z = self.student_head(y)
        return z

    def forward_teacher(self, x):
        y = self.teacher_backbone(x).flatten(start_dim=1)
        z = self.teacher_head(y)
        return z

# %%
import torchvision

# --- Build same backbone as used for DINO pretraining ---
resnet = torchvision.models.resnet18()
# resnet = torchvision.models.resnet34()
backbone = nn.Sequential(*list(resnet.children())[:-1])  # (B, 512, 1, 1)
input_dim = 512

dino_model = DINO(backbone, input_dim)

# --- Load your pre-trained DINO checkpoint ---
# ckpt = torch.load(
#     "/home/long/code/dl_project1/experiments/outputs/dino-v1/dino-v1_small_100.pt",
#     map_location="cpu",
# )

# ckpt = torch.load(
#     "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18.pt",
#     map_location="cpu",
# )

# ckpt18_path = 
ckpt = torch.load(
    "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data3.pt",
    map_location="cpu",
)

dino_model.load_state_dict(ckpt["model_state"], strict=True)
# Out:
# /home/long/code/environments/wejepa/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# <All keys matched successfully>

# %%
from lightly.loss import DINOLoss
from lightly.models.modules import DINOProjectionHead
from lightly.models.utils import deactivate_requires_grad, update_momentum
from lightly.transforms.dino_transform import DINOTransform
from lightly.utils.scheduler import cosine_schedule

# %%
# Freeze everything (linear probe only)
for p in dino_model.parameters():
    p.requires_grad = False

dino_model.eval()
print("done")
# Out:
# done

# %%
# Only train the classifier
device = "cuda:2" if torch.cuda.is_available() else "cpu"

# %%
class DINOEncoderWrapper(nn.Module):
    """Wraps the DINO student backbone and returns a flat feature vector."""

    def __init__(self, dino_model):
        super().__init__()
        self.backbone = dino_model.student_backbone

    def forward(self, x):
        feats = self.backbone(x)          # (B, 512, 1, 1) for ResNet18 backbone
        if isinstance(feats, (list, tuple)):
            feats = feats[0]
        feats = feats.flatten(1)          # (B, 512)
        return feats

class LinearProbeModel(nn.Module):
    def __init__(self, encoder, classifier):
        super().__init__()
        self.encoder = encoder
        self.classifier = classifier

    def forward(self, x):
        with torch.no_grad():              # encoder frozen
            feats = self.encoder(x)
            # feats = feats.flatten(1)
        logits = self.classifier(feats)
        return logits



import math
import torch
import torch.nn as nn

class DINOEncoderWrapper(nn.Module):
    """Wraps the DINO student backbone and returns a 1024-dim flat feature vector."""
    def __init__(self, dino_model, in_dim=512, proj_dim=1024):
        super().__init__()
        self.backbone = dino_model.student_backbone

        # ----- Fixed, non-trainable projection: (in_dim -> proj_dim) -----
        proj = torch.randn(in_dim, proj_dim) / math.sqrt(in_dim)
        # register as a buffer so it's moved with .to(device) but NOT a parameter
        self.register_buffer("proj", proj)

        # (optional) also freeze backbone params explicitly
        for p in self.backbone.parameters():
            p.requires_grad = False

    def forward(self, x):
        feats = self.backbone(x)          # (B, 512, 1, 1) for ResNet18 backbone
        if isinstance(feats, (list, tuple)):
            feats = feats[0]
        feats = feats.flatten(1)          # (B, 512)
        feats = feats @ self.proj         # (B, 1024), fixed linear map
        return feats


NUM_CLASSES = train_df['class_id'].nunique()

print(NUM_CLASSES," total classes")

# feat_dim   = 512  # ResNet18 backbone
feat_dim   = 512  # ResNet18 backbone
classifier = nn.Linear(feat_dim, NUM_CLASSES)
# model = dino_model.to(device)
encoder = DINOEncoderWrapper(dino_model)
model   = LinearProbeModel(encoder, classifier).to(device)
# Out:
# 397  total classes

# %%
import math
import torch
import torch.nn as nn
import torchvision

device = "cuda:3" if torch.cuda.is_available() else "cpu"

# -------------------------------
# 1. DINO encoder wrapper (same idea as yours)
# -------------------------------
class DINOEncoderWrapper(nn.Module):
    """Wraps the DINO student backbone and returns a flat feature vector."""
    def __init__(self, dino_model):
        super().__init__()
        self.backbone = dino_model.student_backbone

        # (optional) extra safety: freeze backbone params
        for p in self.backbone.parameters():
            p.requires_grad = False

    def forward(self, x):
        feats = self.backbone(x)          # (B, 512, 1, 1) for ResNet18/34
        if isinstance(feats, (list, tuple)):
            feats = feats[0]
        feats = feats.flatten(1)          # (B, 512)
        return feats

# -------------------------------
# 2. Build DINO18 and DINO34 models from ckpts
# -------------------------------
# paths to your checkpoints
# ckpt18_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18.pt"
# ckpt18_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data2.pt"
ckpt18_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data3.pt"

ckpt34_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_big_boi_test_fixed.pt"

# ---- ResNet18 backbone ----
resnet18 = torchvision.models.resnet18()
backbone18 = nn.Sequential(*list(resnet18.children())[:-1])  # (B, 512, 1, 1)
in_dim18 = 512

dino18_model = DINO(backbone18, in_dim18)
ckpt18 = torch.load(ckpt18_path, map_location="cpu")
dino18_model.load_state_dict(ckpt18["model_state"], strict=True)
dino18_model.to(device)

# ---- ResNet34 backbone ----
resnet34 = torchvision.models.resnet34()
backbone34 = nn.Sequential(*list(resnet34.children())[:-1])  # (B, 512, 1, 1)
in_dim34 = 512

dino34_model = DINO(backbone34, in_dim34)
ckpt34 = torch.load(ckpt34_path, map_location="cpu")
dino34_model.load_state_dict(ckpt34["model_state"], strict=True)
dino34_model.to(device)

# -------------------------------
# 3. Wrap each into an encoder
# -------------------------------
encoder18 = DINOEncoderWrapper(dino18_model).to(device)
encoder34 = DINOEncoderWrapper(dino34_model).to(device)

# -------------------------------
# 4. Concat encoder
# -------------------------------
class ConcatEncoder(nn.Module):
    """Runs both encoders and concatenates their features."""
    def __init__(self, enc18, enc34):
        super().__init__()
        self.enc18 = enc18
        self.enc34 = enc34

        # freeze everything inside concat encoder (just in case)
        for p in self.parameters():
            p.requires_grad = False

    def forward(self, x):
        f18 = self.enc18(x)   # (B, 512)
        f34 = self.enc34(x)   # (B, 512)
        return torch.cat([f18, f34], dim=1)  # (B, 1024)

concat_encoder = ConcatEncoder(encoder18, encoder34).to(device)

# -------------------------------
# 5. Linear probe on top of concatenated features
# -------------------------------
NUM_CLASSES = train_df["class_id"].nunique()
feat_dim_concat = 512 * 2  # 1024

classifier_concat = nn.Linear(feat_dim_concat, NUM_CLASSES).to(device)

class LinearProbeModel(nn.Module):
    def __init__(self, encoder, classifier):
        super().__init__()
        self.encoder = encoder
        self.classifier = classifier

    def forward(self, x):
        with torch.no_grad():          # encoder frozen
            feats = self.encoder(x)    # (B, 1024)
        logits = self.classifier(feats)
        return logits

model = LinearProbeModel(concat_encoder, classifier_concat).to(device)

# %%
import math
import torch
import torch.nn as nn
import torchvision

device = "cuda:3" if torch.cuda.is_available() else "cpu"

# -------------------------------
# 1. DINO encoder wrapper
# -------------------------------
class DINOEncoderWrapper(nn.Module):
    """Wraps the DINO student backbone and returns a flat feature vector."""
    def __init__(self, dino_model):
        super().__init__()
        self.backbone = dino_model.student_backbone

        # freeze backbone params
        for p in self.backbone.parameters():
            p.requires_grad = False

    def forward(self, x):
        feats = self.backbone(x)          # (B, 512, 1, 1)
        if isinstance(feats, (list, tuple)):
            feats = feats[0]
        feats = feats.flatten(1)          # (B, 512)
        return feats

# -------------------------------
# 2. Build DINO18 (A), DINO18 (B) and DINO34 from ckpts
# -------------------------------
# ckpt18_a_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data2.pt"
ckpt18_a_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data3.pt"

ckpt18_b_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed.pt"
ckpt34_path   = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_big_boi_test_fixed.pt"

# ---- ResNet18 backbone A ----
resnet18_a = torchvision.models.resnet18()
backbone18_a = nn.Sequential(*list(resnet18_a.children())[:-1])  # (B, 512, 1, 1)
in_dim18 = 512

dino18_a = DINO(backbone18_a, in_dim18)
ckpt18_a = torch.load(ckpt18_a_path, map_location="cpu")
dino18_a.load_state_dict(ckpt18_a["model_state"], strict=True)
dino18_a.to(device)

# ---- ResNet18 backbone B (second checkpoint) ----
resnet18_b = torchvision.models.resnet18()
backbone18_b = nn.Sequential(*list(resnet18_b.children())[:-1])
dino18_b = DINO(backbone18_b, in_dim18)
ckpt18_b = torch.load(ckpt18_b_path, map_location="cpu")
dino18_b.load_state_dict(ckpt18_b["model_state"], strict=True)
dino18_b.to(device)

# ---- ResNet34 backbone ----
resnet34 = torchvision.models.resnet34()
backbone34 = nn.Sequential(*list(resnet34.children())[:-1])  # (B, 512, 1, 1)
in_dim34 = 512

dino34 = DINO(backbone34, in_dim34)
ckpt34 = torch.load(ckpt34_path, map_location="cpu")
dino34.load_state_dict(ckpt34["model_state"], strict=True)
dino34.to(device)

# -------------------------------
# 3. Wrap each into an encoder
# -------------------------------
encoder18_a = DINOEncoderWrapper(dino18_a).to(device)
encoder18_b = DINOEncoderWrapper(dino18_b).to(device)
encoder34   = DINOEncoderWrapper(dino34).to(device)

# -------------------------------
# 4. Concat encoder (3-way)
# -------------------------------
class ConcatEncoder(nn.Module):
    """Runs three encoders and concatenates their features."""
    def __init__(self, enc18_a, enc18_b, enc34):
        super().__init__()
        self.enc18_a = enc18_a
        self.enc18_b = enc18_b
        self.enc34   = enc34

        # freeze everything inside concat encoder
        for p in self.parameters():
            p.requires_grad = False

    def forward(self, x):
        f18_a = self.enc18_a(x)   # (B, 512)
        f18_b = self.enc18_b(x)   # (B, 512)
        f34   = self.enc34(x)     # (B, 512)
        return torch.cat([f18_a, f18_b, f34], dim=1)  # (B, 1536)

concat_encoder = ConcatEncoder(encoder18_a, encoder18_b, encoder34).to(device)

# -------------------------------
# 5. Linear probe on top of concatenated features
# -------------------------------
NUM_CLASSES = train_df["class_id"].nunique()
feat_dim_concat = 512 * 3  # 1536

classifier_concat = nn.Linear(feat_dim_concat, NUM_CLASSES).to(device)

class LinearProbeModel(nn.Module):
    def __init__(self, encoder, classifier):
        super().__init__()
        self.encoder = encoder
        self.classifier = classifier

    def forward(self, x):
        with torch.no_grad():          # encoder frozen
            feats = self.encoder(x)    # (B, 1536)
        logits = self.classifier(feats)
        return logits

model = LinearProbeModel(concat_encoder, classifier_concat).to(device)

# %%
#all encoders
import math
import torch
import torch.nn as nn
import torchvision

device = "cuda:3" if torch.cuda.is_available() else "cpu"

# -------------------------------
# 1. DINO encoder wrapper
# -------------------------------
class DINOEncoderWrapper(nn.Module):
    """Wraps the DINO student backbone and returns a flat feature vector."""
    def __init__(self, dino_model):
        super().__init__()
        self.backbone = dino_model.student_backbone

        # freeze backbone params
        for p in self.backbone.parameters():
            p.requires_grad = False

    def forward(self, x):
        feats = self.backbone(x)          # (B, 512, 1, 1)
        if isinstance(feats, (list, tuple)):
            feats = feats[0]
        feats = feats.flatten(1)          # (B, 512)
        return feats

# -------------------------------
# 2. Build DINO18 (A,B,C,D) and DINO34 from ckpts
# -------------------------------
ckpt18_a_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data3.pt"
ckpt18_b_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed.pt"
ckpt18_c_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data2.pt"
ckpt18_d_path = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_18_test2fixed_data1_data1againidk.pt"
ckpt34_path   = "/home/long/code/amogh/data/models/dino-v1_full_finetuned_big_boi_test_fixed.pt"

in_dim18 = 512
in_dim34 = 512

# ---- ResNet18 backbone A ----
resnet18_a = torchvision.models.resnet18()
backbone18_a = nn.Sequential(*list(resnet18_a.children())[:-1])  # (B, 512, 1, 1)
dino18_a = DINO(backbone18_a, in_dim18)
ckpt18_a = torch.load(ckpt18_a_path, map_location="cpu")
dino18_a.load_state_dict(ckpt18_a["model_state"], strict=True)
dino18_a.to(device)

# ---- ResNet18 backbone B ----
resnet18_b = torchvision.models.resnet18()
backbone18_b = nn.Sequential(*list(resnet18_b.children())[:-1])
dino18_b = DINO(backbone18_b, in_dim18)
ckpt18_b = torch.load(ckpt18_b_path, map_location="cpu")
dino18_b.load_state_dict(ckpt18_b["model_state"], strict=True)
dino18_b.to(device)

# ---- ResNet18 backbone C ----
resnet18_c = torchvision.models.resnet18()
backbone18_c = nn.Sequential(*list(resnet18_c.children())[:-1])
dino18_c = DINO(backbone18_c, in_dim18)
ckpt18_c = torch.load(ckpt18_c_path, map_location="cpu")
dino18_c.load_state_dict(ckpt18_c["model_state"], strict=True)
dino18_c.to(device)

# ---- ResNet18 backbone D ----
resnet18_d = torchvision.models.resnet18()
backbone18_d = nn.Sequential(*list(resnet18_d.children())[:-1])
dino18_d = DINO(backbone18_d, in_dim18)
ckpt18_d = torch.load(ckpt18_d_path, map_location="cpu")
dino18_d.load_state_dict(ckpt18_d["model_state"], strict=True)
dino18_d.to(device)

# ---- ResNet34 backbone ----
resnet34 = torchvision.models.resnet34()
backbone34 = nn.Sequential(*list(resnet34.children())[:-1])  # (B, 512, 1, 1)
dino34 = DINO(backbone34, in_dim34)
ckpt34 = torch.load(ckpt34_path, map_location="cpu")
dino34.load_state_dict(ckpt34["model_state"], strict=True)
dino34.to(device)

# -------------------------------
# 3. Wrap each into an encoder
# -------------------------------
encoder18_a = DINOEncoderWrapper(dino18_a).to(device)
encoder18_b = DINOEncoderWrapper(dino18_b).to(device)
encoder18_c = DINOEncoderWrapper(dino18_c).to(device)
encoder18_d = DINOEncoderWrapper(dino18_d).to(device)
encoder34   = DINOEncoderWrapper(dino34).to(device)

# -------------------------------
# 4. Concat encoder (5-way)
# -------------------------------
class ConcatEncoder(nn.Module):
    """Runs five encoders and concatenates their features."""
    def __init__(self, enc18_a, enc18_b, enc18_c, enc18_d, enc34):
        super().__init__()
        self.enc18_a = enc18_a
        self.enc18_b = enc18_b
        self.enc18_c = enc18_c
        self.enc18_d = enc18_d
        self.enc34   = enc34

        # freeze everything inside concat encoder
        for p in self.parameters():
            p.requires_grad = False

    def forward(self, x):
        f18_a = self.enc18_a(x)   # (B, 512)
        f18_b = self.enc18_b(x)   # (B, 512)
        f18_c = self.enc18_c(x)   # (B, 512)
        f18_d = self.enc18_d(x)   # (B, 512)
        f34   = self.enc34(x)     # (B, 512)
        return torch.cat([f18_a, f18_b, f18_c, f18_d, f34], dim=1)  # (B, 2560)

concat_encoder = ConcatEncoder(
    encoder18_a, encoder18_b, encoder18_c, encoder18_d, encoder34
).to(device)

# -------------------------------
# 5. Linear probe on top of concatenated features
# -------------------------------
NUM_CLASSES = train_df["class_id"].nunique()
feat_dim_concat = 512 * 5  # 2560

classifier_concat = nn.Linear(feat_dim_concat, NUM_CLASSES).to(device)

class LinearProbeModel(nn.Module):
    def __init__(self, encoder, classifier):
        super().__init__()
        self.encoder = encoder
        self.classifier = classifier

    def forward(self, x):
        with torch.no_grad():          # encoder frozen
            feats = self.encoder(x)    # (B, 2560)
        logits = self.classifier(feats)
        return logits

model = LinearProbeModel(concat_encoder, classifier_concat).to(device)

# %%
def count_params(model):
    return sum(p.numel() for p in model.parameters())

# %%
total_params = count_params(concat_encoder)
print("Total parameters in concat encoder:", total_params)
# Out:
# Total parameters in concat encoder: 65990720

# %%
device
# Out:
# 'cuda:3'

# %%
print(f"Using device: {device}")

params = list(model.classifier.parameters())
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(
    params,
    lr=3e-3,          # tune between 1e-3 and 3e-3
    weight_decay=1e-4
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=50,         # num_epochs
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# Using device: cuda:3
# /tmp/ipykernel_2441100/386410037.py:15: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %%
# --- Combine train + val ---
from torch.utils.data import ConcatDataset, DataLoader

trainval_ds = ConcatDataset([train_dataset1, val_dataset1])

trainval_loader = DataLoader(
    trainval_ds,
    batch_size=64,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
    persistent_workers=True,
)

# %%
# Only train the classifier
# device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

params = list(model.classifier.parameters())
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(
    params,
    lr=3e-3,          # tune between 1e-3 and 3e-3
    weight_decay=1e-4
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=50,         # num_epochs
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# Using device: cuda:3
# /tmp/ipykernel_2441100/2301509000.py:17: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from tqdm import tqdm

encoder = model.encoder.to(device)
encoder.eval()
for p in encoder.parameters():
    p.requires_grad = False


@torch.no_grad()
def extract_features(encoder, loader, device, desc="Extracting"):
    encoder.eval()
    all_feats = []
    all_labels = []

    # tqdm wrapper around the dataloader
    for batch in tqdm(loader, desc=desc):
        if len(batch) == 3:
            images, labels, _ = batch
        else:
            images, labels = batch

        images = images.to(device, non_blocking=True)

        feats = encoder(images)   # shape: (B, C, H, W) or (B, D)
        if feats.dim() > 2:
            feats = feats.flatten(1)  # (B, D)

        all_feats.append(feats.cpu())
        all_labels.append(labels.cpu())

    all_feats = torch.cat(all_feats, dim=0)   # (N, D)
    all_labels = torch.cat(all_labels, dim=0) # (N,)
    return all_feats, all_labels


print("Extracting train+val features...")
trainval_feats, trainval_labels = extract_features(
    encoder, trainval_loader, device, desc="Train/Val"
)

print("Extracting test features...")
test_feats, test_labels = extract_features(
    encoder, test_loader1, device, desc="Test"
)

feat_dim = trainval_feats.shape[1]
num_classes = int(trainval_labels.max().item() + 1)

print(f"Feature dim = {feat_dim}, num_classes = {num_classes}")
# Out:
# Extracting train+val features...
# Train/Val: 100%|████████████████████████████████████████████████████████████████████████████████████| 264/264 [00:48<00:00,  5.47it/s]
# Extracting test features...
# Test: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 47/47 [00:10<00:00,  4.60it/s]
# Feature dim = 2560, num_classes = 397

# %%
trainval_feat_ds = TensorDataset(trainval_feats, trainval_labels)
test_feat_ds     = TensorDataset(test_feats,     test_labels)

feat_batch_size = 512  # can be big, it's cheap now
# feat_batch_size = 512  # can be big, it's cheap now

trainval_feat_loader = DataLoader(
    trainval_feat_ds, batch_size=feat_batch_size,
    shuffle=True, num_workers=0
)

test_feat_loader = DataLoader(
    test_feat_ds, batch_size=feat_batch_size,
    shuffle=False, num_workers=0
)

# %%
import torch.nn as nn

# linear_head = nn.Linear(feat_dim, num_classes).to(device)
import torch.nn as nn

dropout_p = 0.25  # try 0.2 / 0.3 / 0.5

linear_head = nn.Sequential(
    nn.Dropout(p=dropout_p),
    nn.Linear(feat_dim, num_classes),
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(linear_head.parameters(), lr=2e-3, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=500)
scaler = torch.cuda.amp.GradScaler()
# Out:
# /tmp/ipykernel_2441100/1179007572.py:16: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %%
def run_epoch_head(head, loader, train=True):
    if train:
        head.train()
    else:
        head.eval()

    running_loss = 0.0
    correct = 0
    total = 0

    for feats, labels in loader:
        feats = feats.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        if train:
            optimizer.zero_grad(set_to_none=True)

        with torch.cuda.amp.autocast():
            logits = head(feats)
            loss = criterion(logits, labels)

        if train:
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        running_loss += loss.item() * labels.size(0)
        _, preds = torch.max(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = running_loss / total
    acc = 100.0 * correct / total
    return avg_loss, acc

# %%
num_epochs = 500
best_test_acc = 0.0
best_epoch = 0

# %%
# num_epochs = 500
# best_test_acc = 0.0
# best_epoch = 0

for epoch in range(1, num_epochs + 1):
    train_loss, train_acc = run_epoch_head(linear_head, trainval_feat_loader, train=True)
    test_loss, test_acc   = run_epoch_head(linear_head, test_feat_loader,   train=False)
    scheduler.step()

    if test_acc > best_test_acc:
        best_test_acc = test_acc
        best_epoch = epoch
        # you can save the head weights here if you want
        torch.save(linear_head.state_dict(), "best_linear_head_2.pt")

    print(
        f"Epoch {epoch:02d} | "
        f"train loss: {train_loss:.4f}, acc: {train_acc:.2f}% | "
        f"test loss: {test_loss:.4f}, acc: {test_acc:.2f}%"
    )

print(f"BEST TEST ACC = {best_test_acc:.2f}% at epoch {best_epoch}")
# Out:
# /tmp/ipykernel_2441100/2854452322.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 01 | train loss: 5.2999, acc: 7.87% | test loss: 4.2723, acc: 16.12%
# Epoch 02 | train loss: 3.7108, acc: 23.33% | test loss: 3.6290, acc: 24.38%
# Epoch 03 | train loss: 3.1834, acc: 31.32% | test loss: 3.4668, acc: 26.76%
# Epoch 04 | train loss: 2.8600, acc: 36.89% | test loss: 3.2599, acc: 28.91%
# Epoch 05 | train loss: 2.5803, acc: 41.23% | test loss: 3.1906, acc: 30.96%
# Epoch 06 | train loss: 2.4021, acc: 45.56% | test loss: 3.1740, acc: 30.62%
# Epoch 07 | train loss: 2.2752, acc: 48.06% | test loss: 3.1362, acc: 31.40%
# Epoch 08 | train loss: 2.1708, acc: 50.63% | test loss: 3.1033, acc: 31.93%
# Epoch 09 | train loss: 1.9955, acc: 53.59% | test loss: 2.9992, acc: 33.21%
# Epoch 10 | train loss: 1.8763, acc: 56.47% | test loss: 3.0498, acc: 33.51%
# Epoch 11 | train loss: 1.8032, acc: 58.45% | test loss: 3.0593, acc: 32.74%
# Epoch 12 | train loss: 1.6828, acc: 60.78% | test loss: 3.0030, acc: 34.39%
# Epoch 13 | train loss: 1.6269, acc: 61.58% | test loss: 2.9663, acc: 34.12%
# Epoch 14 | train loss: 1.5571, acc: 64.18% | test loss: 2.9641, acc: 35.36%
# Epoch 15 | train loss: 1.4876, acc: 65.86% | test loss: 2.9761, acc: 35.36%
# Epoch 16 | train loss: 1.4275, acc: 66.83% | test loss: 2.9972, acc: 35.80%
# Epoch 17 | train loss: 1.3481, acc: 69.23% | test loss: 2.9240, acc: 35.73%
# Epoch 18 | train loss: 1.2764, acc: 70.96% | test loss: 2.9197, acc: 35.26%
# Epoch 19 | train loss: 1.2188, acc: 72.23% | test loss: 2.9028, acc: 36.00%
# Epoch 20 | train loss: 1.1726, acc: 73.14% | test loss: 2.9261, acc: 36.33%
# Epoch 21 | train loss: 1.1356, acc: 74.00% | test loss: 2.8941, acc: 35.63%
# Epoch 22 | train loss: 1.0952, acc: 75.21% | test loss: 2.9849, acc: 35.39%
# Epoch 23 | train loss: 1.0646, acc: 76.19% | test loss: 2.9651, acc: 36.03%
# Epoch 24 | train loss: 0.9973, acc: 77.73% | test loss: 2.9224, acc: 36.64%
# Epoch 25 | train loss: 0.9797, acc: 78.31% | test loss: 2.9424, acc: 36.37%
# Epoch 26 | train loss: 0.9475, acc: 79.20% | test loss: 2.9440, acc: 36.30%
# Epoch 27 | train loss: 0.9188, acc: 80.49% | test loss: 2.9184, acc: 36.27%
# Epoch 28 | train loss: 0.8711, acc: 80.76% | test loss: 2.9376, acc: 36.40%
# Epoch 29 | train loss: 0.8435, acc: 82.12% | test loss: 2.8601, acc: 36.60%
# Epoch 30 | train loss: 0.7985, acc: 82.50% | test loss: 2.9028, acc: 37.61%
# Epoch 31 | train loss: 0.7736, acc: 83.39% | test loss: 2.9239, acc: 37.54%
# Epoch 32 | train loss: 0.7622, acc: 83.60% | test loss: 2.9010, acc: 37.17%
# Epoch 33 | train loss: 0.7547, acc: 84.26% | test loss: 2.9181, acc: 36.80%
# Epoch 34 | train loss: 0.7144, acc: 85.19% | test loss: 2.9062, acc: 37.98%
# Epoch 35 | train loss: 0.6945, acc: 85.78% | test loss: 2.9933, acc: 36.80%
# Epoch 36 | train loss: 0.6919, acc: 85.79% | test loss: 2.9792, acc: 36.84%
# Epoch 37 | train loss: 0.6678, acc: 86.33% | test loss: 3.0056, acc: 37.47%
# Epoch 38 | train loss: 0.6440, acc: 86.77% | test loss: 2.9770, acc: 36.87%
# Epoch 39 | train loss: 0.6266, acc: 86.90% | test loss: 2.9670, acc: 37.07%
# Epoch 40 | train loss: 0.5901, acc: 88.18% | test loss: 2.9417, acc: 37.27%
# Epoch 41 | train loss: 0.5863, acc: 88.16% | test loss: 2.9790, acc: 37.64%
# Epoch 42 | train loss: 0.5665, acc: 88.33% | test loss: 2.9587, acc: 38.28%
# Epoch 43 | train loss: 0.5699, acc: 88.60% | test loss: 2.9156, acc: 37.47%
# Epoch 44 | train loss: 0.5066, acc: 90.04% | test loss: 2.9329, acc: 38.28%
# Epoch 45 | train loss: 0.5355, acc: 89.48% | test loss: 2.9710, acc: 36.84%
# Epoch 46 | train loss: 0.5165, acc: 89.44% | test loss: 2.9851, acc: 37.61%
# Epoch 47 | train loss: 0.5055, acc: 90.16% | test loss: 3.0007, acc: 36.90%
# Epoch 48 | train loss: 0.4843, acc: 90.91% | test loss: 2.9857, acc: 37.34%
# Epoch 49 | train loss: 0.4577, acc: 90.96% | test loss: 3.0291, acc: 37.24%
# Epoch 50 | train loss: 0.4643, acc: 91.12% | test loss: 2.9997, acc: 37.61%
# Epoch 51 | train loss: 0.4781, acc: 90.87% | test loss: 3.0739, acc: 37.54%
# Epoch 52 | train loss: 0.4724, acc: 90.88% | test loss: 2.9889, acc: 38.28%
# Epoch 53 | train loss: 0.4253, acc: 91.68% | test loss: 3.0033, acc: 38.11%
# Epoch 54 | train loss: 0.4327, acc: 91.73% | test loss: 3.1126, acc: 36.97%
# Epoch 55 | train loss: 0.4536, acc: 91.55% | test loss: 3.1226, acc: 37.64%
# Epoch 56 | train loss: 0.4213, acc: 92.16% | test loss: 3.0606, acc: 37.11%
# Epoch 57 | train loss: 0.3895, acc: 92.66% | test loss: 3.0385, acc: 37.37%
# Epoch 58 | train loss: 0.3895, acc: 92.91% | test loss: 3.0219, acc: 37.71%
# Epoch 59 | train loss: 0.3805, acc: 93.16% | test loss: 3.0501, acc: 37.58%
# Epoch 60 | train loss: 0.3628, acc: 93.08% | test loss: 3.0829, acc: 37.00%
# Epoch 61 | train loss: 0.3620, acc: 93.20% | test loss: 3.0725, acc: 37.44%
# Epoch 62 | train loss: 0.3682, acc: 93.12% | test loss: 3.0732, acc: 38.58%
# Epoch 63 | train loss: 0.3506, acc: 93.41% | test loss: 3.0856, acc: 36.97%
# Epoch 64 | train loss: 0.3372, acc: 93.68% | test loss: 3.0802, acc: 37.78%
# Epoch 65 | train loss: 0.3505, acc: 93.61% | test loss: 3.1721, acc: 37.41%
# Epoch 66 | train loss: 0.3464, acc: 93.62% | test loss: 3.1048, acc: 37.34%
# Epoch 67 | train loss: 0.3417, acc: 93.70% | test loss: 3.0518, acc: 37.78%
# Epoch 68 | train loss: 0.3404, acc: 94.27% | test loss: 3.1895, acc: 36.70%
# Epoch 69 | train loss: 0.3557, acc: 93.49% | test loss: 3.1847, acc: 36.87%
# Epoch 70 | train loss: 0.3412, acc: 93.63% | test loss: 3.1979, acc: 37.11%
# Epoch 71 | train loss: 0.3174, acc: 94.10% | test loss: 3.1245, acc: 37.78%
# Epoch 72 | train loss: 0.3097, acc: 94.56% | test loss: 3.1277, acc: 37.78%
# Epoch 73 | train loss: 0.2863, acc: 94.62% | test loss: 3.0903, acc: 37.47%
# Epoch 74 | train loss: 0.2774, acc: 94.94% | test loss: 3.1370, acc: 37.88%
# Epoch 75 | train loss: 0.2835, acc: 95.05% | test loss: 3.1214, acc: 37.74%
# Epoch 76 | train loss: 0.2729, acc: 95.22% | test loss: 3.1243, acc: 37.84%
# Epoch 77 | train loss: 0.2622, acc: 95.37% | test loss: 3.0935, acc: 37.58%
# Epoch 78 | train loss: 0.2631, acc: 95.30% | test loss: 3.1099, acc: 37.51%
# Epoch 79 | train loss: 0.2538, acc: 95.74% | test loss: 3.1628, acc: 38.52%
# Epoch 80 | train loss: 0.2689, acc: 95.32% | test loss: 3.1964, acc: 37.51%
# Epoch 81 | train loss: 0.2925, acc: 94.76% | test loss: 3.2358, acc: 36.77%
# Epoch 82 | train loss: 0.2766, acc: 94.55% | test loss: 3.2256, acc: 36.97%
# Epoch 83 | train loss: 0.2498, acc: 95.51% | test loss: 3.2067, acc: 37.44%
# Epoch 84 | train loss: 0.2556, acc: 95.33% | test loss: 3.1536, acc: 38.89%
# Epoch 85 | train loss: 0.2468, acc: 95.50% | test loss: 3.1606, acc: 38.01%
# Epoch 86 | train loss: 0.2654, acc: 95.38% | test loss: 3.2802, acc: 36.90%
# Epoch 87 | train loss: 0.2589, acc: 95.26% | test loss: 3.2698, acc: 37.58%
# Epoch 88 | train loss: 0.2534, acc: 95.25% | test loss: 3.2444, acc: 37.47%
# Epoch 89 | train loss: 0.2407, acc: 95.69% | test loss: 3.2250, acc: 37.64%
# Epoch 90 | train loss: 0.2261, acc: 96.00% | test loss: 3.2022, acc: 37.71%
# Epoch 91 | train loss: 0.2317, acc: 95.83% | test loss: 3.2837, acc: 37.54%
# Epoch 92 | train loss: 0.2270, acc: 96.09% | test loss: 3.2323, acc: 37.84%
# Epoch 93 | train loss: 0.2191, acc: 96.17% | test loss: 3.2333, acc: 37.54%
# Epoch 94 | train loss: 0.2189, acc: 95.96% | test loss: 3.2174, acc: 38.58%
# Epoch 95 | train loss: 0.2036, acc: 96.57% | test loss: 3.2117, acc: 38.15%
# Epoch 96 | train loss: 0.2119, acc: 96.16% | test loss: 3.2922, acc: 37.64%
# Epoch 97 | train loss: 0.2324, acc: 95.79% | test loss: 3.2977, acc: 37.64%
# Epoch 98 | train loss: 0.2251, acc: 96.00% | test loss: 3.2728, acc: 37.98%
# Epoch 99 | train loss: 0.2100, acc: 96.27% | test loss: 3.3483, acc: 37.74%
# Epoch 100 | train loss: 0.2091, acc: 96.40% | test loss: 3.2458, acc: 38.38%
# Epoch 101 | train loss: 0.2064, acc: 96.29% | test loss: 3.2745, acc: 37.47%
# Epoch 102 | train loss: 0.1906, acc: 96.33% | test loss: 3.3227, acc: 37.31%
# Epoch 103 | train loss: 0.1947, acc: 96.56% | test loss: 3.2685, acc: 38.31%
# Epoch 104 | train loss: 0.1742, acc: 96.86% | test loss: 3.2395, acc: 38.31%
# Epoch 105 | train loss: 0.1754, acc: 96.83% | test loss: 3.3885, acc: 36.67%
# Epoch 106 | train loss: 0.1958, acc: 96.57% | test loss: 3.2807, acc: 38.08%
# Epoch 107 | train loss: 0.1971, acc: 96.26% | test loss: 3.3452, acc: 37.78%
# Epoch 108 | train loss: 0.1900, acc: 96.37% | test loss: 3.3250, acc: 37.84%
# Epoch 109 | train loss: 0.1831, acc: 96.57% | test loss: 3.3511, acc: 37.94%
# Epoch 110 | train loss: 0.1833, acc: 96.76% | test loss: 3.2987, acc: 37.88%
# Epoch 111 | train loss: 0.1806, acc: 96.85% | test loss: 3.4054, acc: 37.47%
# Epoch 112 | train loss: 0.1908, acc: 96.85% | test loss: 3.3942, acc: 37.81%
# Epoch 113 | train loss: 0.1858, acc: 96.46% | test loss: 3.3586, acc: 38.15%
# Epoch 114 | train loss: 0.1581, acc: 97.50% | test loss: 3.2823, acc: 38.55%
# Epoch 115 | train loss: 0.1621, acc: 97.22% | test loss: 3.3730, acc: 37.68%
# Epoch 116 | train loss: 0.1958, acc: 96.57% | test loss: 3.3988, acc: 36.90%
# Epoch 117 | train loss: 0.1862, acc: 96.30% | test loss: 3.4867, acc: 37.64%
# Epoch 118 | train loss: 0.1763, acc: 96.86% | test loss: 3.3916, acc: 37.64%
# Epoch 119 | train loss: 0.1613, acc: 97.07% | test loss: 3.3675, acc: 37.61%
# Epoch 120 | train loss: 0.1638, acc: 97.22% | test loss: 3.3660, acc: 37.54%
# Epoch 121 | train loss: 0.1794, acc: 96.78% | test loss: 3.4259, acc: 36.50%
# Epoch 122 | train loss: 0.1727, acc: 96.89% | test loss: 3.4685, acc: 37.98%
# Epoch 123 | train loss: 0.1692, acc: 96.89% | test loss: 3.4299, acc: 37.74%
# Epoch 124 | train loss: 0.1586, acc: 97.28% | test loss: 3.4377, acc: 37.98%
# Epoch 125 | train loss: 0.1604, acc: 97.07% | test loss: 3.3782, acc: 38.42%
# Epoch 126 | train loss: 0.1642, acc: 97.02% | test loss: 3.4003, acc: 37.84%
# Epoch 127 | train loss: 0.1506, acc: 97.21% | test loss: 3.3899, acc: 37.61%
# Epoch 128 | train loss: 0.1396, acc: 97.39% | test loss: 3.3829, acc: 37.98%
# Epoch 129 | train loss: 0.1341, acc: 97.56% | test loss: 3.4387, acc: 38.11%
# Epoch 130 | train loss: 0.1463, acc: 97.29% | test loss: 3.3986, acc: 38.31%
# Epoch 131 | train loss: 0.1435, acc: 97.36% | test loss: 3.4431, acc: 37.58%
# Epoch 132 | train loss: 0.1359, acc: 97.50% | test loss: 3.3951, acc: 38.11%
# Epoch 133 | train loss: 0.1299, acc: 97.62% | test loss: 3.3943, acc: 38.08%
# Epoch 134 | train loss: 0.1276, acc: 97.68% | test loss: 3.4704, acc: 37.37%
# Epoch 135 | train loss: 0.1411, acc: 97.34% | test loss: 3.4411, acc: 38.28%
# Epoch 136 | train loss: 0.1435, acc: 97.40% | test loss: 3.5044, acc: 37.37%
# Epoch 137 | train loss: 0.1346, acc: 97.43% | test loss: 3.4239, acc: 38.15%
# Epoch 138 | train loss: 0.1329, acc: 97.49% | test loss: 3.4425, acc: 37.24%
# Epoch 139 | train loss: 0.1353, acc: 97.42% | test loss: 3.5178, acc: 37.84%
# Epoch 140 | train loss: 0.1423, acc: 97.45% | test loss: 3.4518, acc: 38.62%
# Epoch 141 | train loss: 0.1328, acc: 97.49% | test loss: 3.4786, acc: 38.11%
# Epoch 142 | train loss: 0.1202, acc: 97.86% | test loss: 3.4326, acc: 38.31%
# Epoch 143 | train loss: 0.1079, acc: 98.19% | test loss: 3.3888, acc: 37.58%
# Epoch 144 | train loss: 0.1185, acc: 97.89% | test loss: 3.4454, acc: 38.01%
# Epoch 145 | train loss: 0.1196, acc: 97.99% | test loss: 3.4704, acc: 37.88%
# Epoch 146 | train loss: 0.1253, acc: 97.72% | test loss: 3.4864, acc: 38.25%
# Epoch 147 | train loss: 0.1202, acc: 97.90% | test loss: 3.4494, acc: 37.88%
# Epoch 148 | train loss: 0.1193, acc: 97.75% | test loss: 3.5272, acc: 38.28%
# Epoch 149 | train loss: 0.1117, acc: 97.91% | test loss: 3.4617, acc: 37.98%
# Epoch 150 | train loss: 0.1048, acc: 98.12% | test loss: 3.4827, acc: 39.02%
# Epoch 151 | train loss: 0.1072, acc: 98.13% | test loss: 3.4873, acc: 38.35%
# Epoch 152 | train loss: 0.1051, acc: 98.16% | test loss: 3.5083, acc: 38.35%
# Epoch 153 | train loss: 0.1063, acc: 98.25% | test loss: 3.5033, acc: 38.21%
# Epoch 154 | train loss: 0.1066, acc: 98.04% | test loss: 3.5094, acc: 38.08%
# Epoch 155 | train loss: 0.0977, acc: 98.29% | test loss: 3.5040, acc: 37.84%
# Epoch 156 | train loss: 0.1050, acc: 98.14% | test loss: 3.5080, acc: 37.91%
# Epoch 157 | train loss: 0.1001, acc: 98.26% | test loss: 3.4892, acc: 37.61%
# Epoch 158 | train loss: 0.1028, acc: 98.14% | test loss: 3.5677, acc: 37.54%
# Epoch 159 | train loss: 0.1164, acc: 97.82% | test loss: 3.5893, acc: 38.08%
# Epoch 160 | train loss: 0.1041, acc: 97.99% | test loss: 3.5230, acc: 38.65%
# Epoch 161 | train loss: 0.0875, acc: 98.54% | test loss: 3.4837, acc: 38.38%
# Epoch 162 | train loss: 0.1139, acc: 98.07% | test loss: 3.5697, acc: 37.88%
# Epoch 163 | train loss: 0.1364, acc: 97.46% | test loss: 3.6818, acc: 37.64%
# Epoch 164 | train loss: 0.1216, acc: 97.84% | test loss: 3.5876, acc: 38.45%
# Epoch 165 | train loss: 0.1224, acc: 97.67% | test loss: 3.6189, acc: 37.54%
# Epoch 166 | train loss: 0.1154, acc: 97.88% | test loss: 3.5974, acc: 38.01%
# Epoch 167 | train loss: 0.1166, acc: 97.90% | test loss: 3.5508, acc: 38.31%
# Epoch 168 | train loss: 0.1076, acc: 98.16% | test loss: 3.6298, acc: 37.71%
# Epoch 169 | train loss: 0.1002, acc: 98.15% | test loss: 3.5490, acc: 37.91%
# Epoch 170 | train loss: 0.0984, acc: 98.24% | test loss: 3.4835, acc: 38.65%
# Epoch 171 | train loss: 0.0843, acc: 98.48% | test loss: 3.5734, acc: 37.91%
# Epoch 172 | train loss: 0.1033, acc: 98.25% | test loss: 3.5626, acc: 38.31%
# Epoch 173 | train loss: 0.1014, acc: 98.31% | test loss: 3.5362, acc: 38.25%
# Epoch 174 | train loss: 0.0979, acc: 98.13% | test loss: 3.6454, acc: 38.31%
# Epoch 175 | train loss: 0.0931, acc: 98.28% | test loss: 3.6112, acc: 38.15%
# Epoch 176 | train loss: 0.0993, acc: 98.11% | test loss: 3.7382, acc: 37.78%
# Epoch 177 | train loss: 0.1108, acc: 97.91% | test loss: 3.6533, acc: 38.21%
# Epoch 178 | train loss: 0.0982, acc: 98.30% | test loss: 3.6509, acc: 37.51%
# Epoch 179 | train loss: 0.1129, acc: 98.04% | test loss: 3.7032, acc: 37.41%
# Epoch 180 | train loss: 0.1175, acc: 97.68% | test loss: 3.6841, acc: 38.45%
# Epoch 181 | train loss: 0.1023, acc: 98.12% | test loss: 3.6309, acc: 37.21%
# Epoch 182 | train loss: 0.0947, acc: 98.36% | test loss: 3.6153, acc: 38.11%
# Epoch 183 | train loss: 0.0883, acc: 98.52% | test loss: 3.6130, acc: 38.38%
# Epoch 184 | train loss: 0.0901, acc: 98.33% | test loss: 3.6730, acc: 37.64%
# Epoch 185 | train loss: 0.1052, acc: 98.06% | test loss: 3.6863, acc: 37.78%
# Epoch 186 | train loss: 0.0998, acc: 98.21% | test loss: 3.6573, acc: 39.12%
# Epoch 187 | train loss: 0.0991, acc: 98.15% | test loss: 3.6984, acc: 38.68%
# Epoch 188 | train loss: 0.0854, acc: 98.38% | test loss: 3.5874, acc: 38.78%
# Epoch 189 | train loss: 0.0818, acc: 98.52% | test loss: 3.6428, acc: 38.68%
# Epoch 190 | train loss: 0.0810, acc: 98.48% | test loss: 3.6034, acc: 39.15%
# Epoch 191 | train loss: 0.0850, acc: 98.26% | test loss: 3.6848, acc: 38.89%
# Epoch 192 | train loss: 0.1047, acc: 98.10% | test loss: 3.6596, acc: 38.15%
# Epoch 193 | train loss: 0.0852, acc: 98.33% | test loss: 3.6431, acc: 38.31%
# Epoch 194 | train loss: 0.0845, acc: 98.53% | test loss: 3.7179, acc: 38.38%
# Epoch 195 | train loss: 0.0895, acc: 98.26% | test loss: 3.6832, acc: 37.74%
# Epoch 196 | train loss: 0.0762, acc: 98.57% | test loss: 3.6478, acc: 37.71%
# Epoch 197 | train loss: 0.0655, acc: 98.95% | test loss: 3.6342, acc: 37.84%
# Epoch 198 | train loss: 0.0692, acc: 98.81% | test loss: 3.6969, acc: 37.68%
# Epoch 199 | train loss: 0.0761, acc: 98.74% | test loss: 3.7559, acc: 37.74%
# Epoch 200 | train loss: 0.0892, acc: 98.45% | test loss: 3.7315, acc: 38.18%
# Epoch 201 | train loss: 0.0857, acc: 98.46% | test loss: 3.7445, acc: 37.14%
# Epoch 202 | train loss: 0.0889, acc: 98.29% | test loss: 3.7748, acc: 36.43%
# Epoch 203 | train loss: 0.0802, acc: 98.46% | test loss: 3.7480, acc: 38.01%
# Epoch 204 | train loss: 0.0758, acc: 98.59% | test loss: 3.6505, acc: 38.48%
# Epoch 205 | train loss: 0.0660, acc: 98.91% | test loss: 3.6494, acc: 38.82%
# Epoch 206 | train loss: 0.0686, acc: 98.82% | test loss: 3.7260, acc: 38.68%
# Epoch 207 | train loss: 0.0760, acc: 98.71% | test loss: 3.6750, acc: 38.48%
# Epoch 208 | train loss: 0.0737, acc: 98.86% | test loss: 3.6908, acc: 37.91%
# Epoch 209 | train loss: 0.0739, acc: 98.58% | test loss: 3.7272, acc: 38.05%
# Epoch 210 | train loss: 0.0721, acc: 98.71% | test loss: 3.6264, acc: 38.31%
# Epoch 211 | train loss: 0.0640, acc: 98.96% | test loss: 3.6153, acc: 38.42%
# Epoch 212 | train loss: 0.0676, acc: 98.71% | test loss: 3.6647, acc: 38.68%
# Epoch 213 | train loss: 0.0628, acc: 98.90% | test loss: 3.6574, acc: 38.05%
# Epoch 214 | train loss: 0.0701, acc: 98.75% | test loss: 3.6711, acc: 37.71%
# Epoch 215 | train loss: 0.0771, acc: 98.67% | test loss: 3.7540, acc: 38.68%
# Epoch 216 | train loss: 0.0760, acc: 98.77% | test loss: 3.7905, acc: 38.28%
# Epoch 217 | train loss: 0.0825, acc: 98.46% | test loss: 3.7840, acc: 38.38%
# Epoch 218 | train loss: 0.0738, acc: 98.54% | test loss: 3.6996, acc: 38.28%
# Epoch 219 | train loss: 0.0668, acc: 98.79% | test loss: 3.6507, acc: 38.52%
# Epoch 220 | train loss: 0.0613, acc: 98.96% | test loss: 3.6415, acc: 37.94%
# Epoch 221 | train loss: 0.0614, acc: 98.91% | test loss: 3.6738, acc: 38.89%
# Epoch 222 | train loss: 0.0578, acc: 98.93% | test loss: 3.6512, acc: 38.05%
# Epoch 223 | train loss: 0.0552, acc: 99.06% | test loss: 3.6831, acc: 38.89%
# Epoch 224 | train loss: 0.0704, acc: 98.72% | test loss: 3.8288, acc: 37.71%
# Epoch 225 | train loss: 0.0815, acc: 98.70% | test loss: 3.7685, acc: 38.01%
# Epoch 226 | train loss: 0.0691, acc: 98.83% | test loss: 3.7541, acc: 37.51%
# Epoch 227 | train loss: 0.0764, acc: 98.63% | test loss: 3.7525, acc: 38.11%
# Epoch 228 | train loss: 0.0676, acc: 98.69% | test loss: 3.7301, acc: 37.81%
# Epoch 229 | train loss: 0.0719, acc: 98.71% | test loss: 3.7200, acc: 38.21%
# Epoch 230 | train loss: 0.0642, acc: 98.90% | test loss: 3.7605, acc: 38.95%
# Epoch 231 | train loss: 0.0706, acc: 98.64% | test loss: 3.7655, acc: 38.68%
# Epoch 232 | train loss: 0.0646, acc: 98.76% | test loss: 3.6833, acc: 38.75%
# Epoch 233 | train loss: 0.0606, acc: 98.90% | test loss: 3.7023, acc: 38.58%
# Epoch 234 | train loss: 0.0598, acc: 98.90% | test loss: 3.7248, acc: 38.15%
# Epoch 235 | train loss: 0.0607, acc: 98.92% | test loss: 3.7426, acc: 38.55%
# Epoch 236 | train loss: 0.0585, acc: 98.99% | test loss: 3.7165, acc: 39.15%
# Epoch 237 | train loss: 0.0546, acc: 99.08% | test loss: 3.7152, acc: 38.21%
# Epoch 238 | train loss: 0.0545, acc: 99.08% | test loss: 3.7279, acc: 39.05%
# Epoch 239 | train loss: 0.0605, acc: 98.99% | test loss: 3.7858, acc: 38.85%
# Epoch 240 | train loss: 0.0633, acc: 98.92% | test loss: 3.7453, acc: 38.65%
# Epoch 241 | train loss: 0.0556, acc: 99.02% | test loss: 3.7365, acc: 38.99%
# Epoch 242 | train loss: 0.0565, acc: 99.05% | test loss: 3.7305, acc: 37.84%
# Epoch 243 | train loss: 0.0546, acc: 99.09% | test loss: 3.7838, acc: 38.05%
# Epoch 244 | train loss: 0.0509, acc: 99.18% | test loss: 3.7160, acc: 39.02%
# Epoch 245 | train loss: 0.0515, acc: 99.10% | test loss: 3.7352, acc: 38.38%
# Epoch 246 | train loss: 0.0510, acc: 99.11% | test loss: 3.7283, acc: 38.48%
# Epoch 247 | train loss: 0.0519, acc: 99.03% | test loss: 3.7162, acc: 38.15%
# Epoch 248 | train loss: 0.0459, acc: 99.31% | test loss: 3.6901, acc: 38.75%
# Epoch 249 | train loss: 0.0519, acc: 99.22% | test loss: 3.7784, acc: 38.62%
# Epoch 250 | train loss: 0.0481, acc: 99.20% | test loss: 3.7301, acc: 38.65%
# Epoch 251 | train loss: 0.0491, acc: 99.24% | test loss: 3.7556, acc: 38.35%
# Epoch 252 | train loss: 0.0528, acc: 99.22% | test loss: 3.6958, acc: 38.05%
# Epoch 253 | train loss: 0.0523, acc: 99.15% | test loss: 3.7151, acc: 38.01%
# Epoch 254 | train loss: 0.0505, acc: 99.21% | test loss: 3.7237, acc: 38.21%
# Epoch 255 | train loss: 0.0479, acc: 99.17% | test loss: 3.7465, acc: 38.42%
# Epoch 256 | train loss: 0.0449, acc: 99.28% | test loss: 3.7316, acc: 38.78%
# Epoch 257 | train loss: 0.0427, acc: 99.38% | test loss: 3.7448, acc: 38.99%
# Epoch 258 | train loss: 0.0494, acc: 99.12% | test loss: 3.7776, acc: 38.28%
# Epoch 259 | train loss: 0.0527, acc: 99.01% | test loss: 3.7730, acc: 39.19%
# Epoch 260 | train loss: 0.0487, acc: 99.17% | test loss: 3.7470, acc: 38.52%
# Epoch 261 | train loss: 0.0485, acc: 99.21% | test loss: 3.7378, acc: 38.52%
# Epoch 262 | train loss: 0.0438, acc: 99.24% | test loss: 3.7380, acc: 38.72%
# Epoch 263 | train loss: 0.0480, acc: 99.13% | test loss: 3.7560, acc: 38.58%
# Epoch 264 | train loss: 0.0416, acc: 99.31% | test loss: 3.7350, acc: 38.28%
# Epoch 265 | train loss: 0.0457, acc: 99.21% | test loss: 3.7308, acc: 38.75%
# Epoch 266 | train loss: 0.0425, acc: 99.27% | test loss: 3.7137, acc: 39.09%
# Epoch 267 | train loss: 0.0456, acc: 99.29% | test loss: 3.7669, acc: 37.68%
# Epoch 268 | train loss: 0.0474, acc: 99.19% | test loss: 3.7416, acc: 38.82%
# Epoch 269 | train loss: 0.0509, acc: 99.18% | test loss: 3.7078, acc: 39.19%
# Epoch 270 | train loss: 0.0511, acc: 99.03% | test loss: 3.7943, acc: 38.62%
# Epoch 271 | train loss: 0.0423, acc: 99.40% | test loss: 3.7525, acc: 38.75%
# Epoch 272 | train loss: 0.0403, acc: 99.39% | test loss: 3.7541, acc: 38.99%
# Epoch 273 | train loss: 0.0546, acc: 99.03% | test loss: 3.8572, acc: 38.75%
# Epoch 274 | train loss: 0.0468, acc: 99.30% | test loss: 3.7777, acc: 37.41%
# Epoch 275 | train loss: 0.0378, acc: 99.41% | test loss: 3.7298, acc: 38.68%
# Epoch 276 | train loss: 0.0413, acc: 99.36% | test loss: 3.7920, acc: 38.65%
# Epoch 277 | train loss: 0.0432, acc: 99.22% | test loss: 3.7746, acc: 39.09%
# Epoch 278 | train loss: 0.0432, acc: 99.28% | test loss: 3.7948, acc: 37.91%
# Epoch 279 | train loss: 0.0413, acc: 99.40% | test loss: 3.7370, acc: 38.99%
# Epoch 280 | train loss: 0.0381, acc: 99.43% | test loss: 3.7879, acc: 38.92%
# Epoch 281 | train loss: 0.0390, acc: 99.40% | test loss: 3.7326, acc: 38.68%
# Epoch 282 | train loss: 0.0410, acc: 99.38% | test loss: 3.7430, acc: 38.75%
# Epoch 283 | train loss: 0.0379, acc: 99.41% | test loss: 3.7268, acc: 38.65%
# Epoch 284 | train loss: 0.0378, acc: 99.57% | test loss: 3.7377, acc: 39.36%
# Epoch 285 | train loss: 0.0356, acc: 99.47% | test loss: 3.7198, acc: 38.78%
# Epoch 286 | train loss: 0.0370, acc: 99.51% | test loss: 3.7243, acc: 39.36%
# Epoch 287 | train loss: 0.0373, acc: 99.49% | test loss: 3.7610, acc: 38.99%
# Epoch 288 | train loss: 0.0403, acc: 99.32% | test loss: 3.7505, acc: 38.85%
# Epoch 289 | train loss: 0.0398, acc: 99.37% | test loss: 3.7704, acc: 38.72%
# Epoch 290 | train loss: 0.0357, acc: 99.45% | test loss: 3.7566, acc: 37.78%
# Epoch 291 | train loss: 0.0425, acc: 99.35% | test loss: 3.7938, acc: 39.36%
# Epoch 292 | train loss: 0.0395, acc: 99.39% | test loss: 3.7489, acc: 38.78%
# Epoch 293 | train loss: 0.0387, acc: 99.48% | test loss: 3.7228, acc: 39.02%
# Epoch 294 | train loss: 0.0347, acc: 99.47% | test loss: 3.7701, acc: 39.05%
# Epoch 295 | train loss: 0.0369, acc: 99.54% | test loss: 3.7656, acc: 38.58%
# Epoch 296 | train loss: 0.0391, acc: 99.36% | test loss: 3.7309, acc: 38.48%
# Epoch 297 | train loss: 0.0356, acc: 99.53% | test loss: 3.7030, acc: 39.15%
# Epoch 298 | train loss: 0.0344, acc: 99.47% | test loss: 3.7535, acc: 38.65%
# Epoch 299 | train loss: 0.0334, acc: 99.48% | test loss: 3.7590, acc: 38.78%
# Epoch 300 | train loss: 0.0306, acc: 99.61% | test loss: 3.7285, acc: 39.09%
# Epoch 301 | train loss: 0.0337, acc: 99.56% | test loss: 3.7653, acc: 38.78%
# Epoch 302 | train loss: 0.0288, acc: 99.72% | test loss: 3.7086, acc: 39.15%
# Epoch 303 | train loss: 0.0293, acc: 99.62% | test loss: 3.7314, acc: 38.82%
# Epoch 304 | train loss: 0.0328, acc: 99.51% | test loss: 3.6989, acc: 39.02%
# Epoch 305 | train loss: 0.0329, acc: 99.55% | test loss: 3.7668, acc: 38.58%
# Epoch 306 | train loss: 0.0342, acc: 99.55% | test loss: 3.7335, acc: 39.12%
# Epoch 307 | train loss: 0.0282, acc: 99.70% | test loss: 3.7041, acc: 39.19%
# Epoch 308 | train loss: 0.0320, acc: 99.56% | test loss: 3.7276, acc: 39.09%
# Epoch 309 | train loss: 0.0295, acc: 99.62% | test loss: 3.7305, acc: 38.75%
# Epoch 310 | train loss: 0.0294, acc: 99.60% | test loss: 3.7346, acc: 38.82%
# Epoch 311 | train loss: 0.0293, acc: 99.68% | test loss: 3.7105, acc: 38.95%
# Epoch 312 | train loss: 0.0315, acc: 99.55% | test loss: 3.7224, acc: 38.68%
# Epoch 313 | train loss: 0.0330, acc: 99.51% | test loss: 3.7947, acc: 38.95%
# Epoch 314 | train loss: 0.0414, acc: 99.53% | test loss: 3.8037, acc: 39.12%
# Epoch 315 | train loss: 0.0422, acc: 99.48% | test loss: 3.7833, acc: 38.65%
# Epoch 316 | train loss: 0.0405, acc: 99.47% | test loss: 3.7557, acc: 38.25%
# Epoch 317 | train loss: 0.0294, acc: 99.61% | test loss: 3.7920, acc: 38.75%
# Epoch 318 | train loss: 0.0343, acc: 99.47% | test loss: 3.7854, acc: 38.28%
# Epoch 319 | train loss: 0.0296, acc: 99.63% | test loss: 3.7451, acc: 38.68%
# Epoch 320 | train loss: 0.0284, acc: 99.60% | test loss: 3.7342, acc: 38.25%
# Epoch 321 | train loss: 0.0281, acc: 99.68% | test loss: 3.6950, acc: 39.66%
# Epoch 322 | train loss: 0.0269, acc: 99.69% | test loss: 3.6975, acc: 39.32%
# Epoch 323 | train loss: 0.0266, acc: 99.72% | test loss: 3.7449, acc: 39.46%
# Epoch 324 | train loss: 0.0281, acc: 99.67% | test loss: 3.7186, acc: 38.72%
# Epoch 325 | train loss: 0.0277, acc: 99.64% | test loss: 3.7345, acc: 39.19%
# Epoch 326 | train loss: 0.0280, acc: 99.59% | test loss: 3.7126, acc: 39.42%
# Epoch 327 | train loss: 0.0273, acc: 99.64% | test loss: 3.7304, acc: 38.95%
# Epoch 328 | train loss: 0.0263, acc: 99.68% | test loss: 3.7126, acc: 39.29%
# Epoch 329 | train loss: 0.0258, acc: 99.73% | test loss: 3.7144, acc: 39.25%
# Epoch 330 | train loss: 0.0261, acc: 99.73% | test loss: 3.7090, acc: 38.89%
# Epoch 331 | train loss: 0.0250, acc: 99.73% | test loss: 3.7014, acc: 39.66%
# Epoch 332 | train loss: 0.0263, acc: 99.73% | test loss: 3.7209, acc: 39.42%
# Epoch 333 | train loss: 0.0269, acc: 99.67% | test loss: 3.7705, acc: 38.95%
# Epoch 334 | train loss: 0.0262, acc: 99.73% | test loss: 3.7069, acc: 39.46%
# Epoch 335 | train loss: 0.0247, acc: 99.75% | test loss: 3.7163, acc: 39.79%
# Epoch 336 | train loss: 0.0248, acc: 99.75% | test loss: 3.7126, acc: 39.89%
# Epoch 337 | train loss: 0.0232, acc: 99.76% | test loss: 3.7399, acc: 39.49%
# Epoch 338 | train loss: 0.0236, acc: 99.76% | test loss: 3.7093, acc: 39.29%
# Epoch 339 | train loss: 0.0226, acc: 99.82% | test loss: 3.7446, acc: 39.56%
# Epoch 340 | train loss: 0.0242, acc: 99.79% | test loss: 3.7330, acc: 39.49%
# Epoch 341 | train loss: 0.0243, acc: 99.73% | test loss: 3.6982, acc: 39.42%
# Epoch 342 | train loss: 0.0252, acc: 99.71% | test loss: 3.7442, acc: 39.12%
# Epoch 343 | train loss: 0.0267, acc: 99.68% | test loss: 3.7366, acc: 39.02%
# Epoch 344 | train loss: 0.0263, acc: 99.70% | test loss: 3.7510, acc: 38.89%
# Epoch 345 | train loss: 0.0268, acc: 99.64% | test loss: 3.7436, acc: 39.22%
# Epoch 346 | train loss: 0.0237, acc: 99.75% | test loss: 3.7460, acc: 39.02%
# Epoch 347 | train loss: 0.0246, acc: 99.73% | test loss: 3.7287, acc: 39.12%
# Epoch 348 | train loss: 0.0236, acc: 99.73% | test loss: 3.7291, acc: 38.72%
# Epoch 349 | train loss: 0.0230, acc: 99.76% | test loss: 3.7458, acc: 39.42%
# Epoch 350 | train loss: 0.0245, acc: 99.68% | test loss: 3.7052, acc: 39.76%
# Epoch 351 | train loss: 0.0241, acc: 99.70% | test loss: 3.7379, acc: 39.79%
# Epoch 352 | train loss: 0.0227, acc: 99.75% | test loss: 3.7453, acc: 38.82%
# Epoch 353 | train loss: 0.0224, acc: 99.78% | test loss: 3.7190, acc: 39.19%
# Epoch 354 | train loss: 0.0224, acc: 99.80% | test loss: 3.7178, acc: 39.39%
# Epoch 355 | train loss: 0.0231, acc: 99.76% | test loss: 3.7249, acc: 38.68%
# Epoch 356 | train loss: 0.0233, acc: 99.77% | test loss: 3.7401, acc: 38.99%
# Epoch 357 | train loss: 0.0245, acc: 99.72% | test loss: 3.7270, acc: 38.25%
# Epoch 358 | train loss: 0.0249, acc: 99.73% | test loss: 3.7119, acc: 39.22%
# Epoch 359 | train loss: 0.0246, acc: 99.76% | test loss: 3.7192, acc: 39.22%
# Epoch 360 | train loss: 0.0226, acc: 99.76% | test loss: 3.6993, acc: 38.89%
# Epoch 361 | train loss: 0.0209, acc: 99.83% | test loss: 3.7096, acc: 39.19%
# Epoch 362 | train loss: 0.0231, acc: 99.70% | test loss: 3.7257, acc: 38.95%
# Epoch 363 | train loss: 0.0216, acc: 99.75% | test loss: 3.7150, acc: 39.32%
# Epoch 364 | train loss: 0.0235, acc: 99.72% | test loss: 3.7586, acc: 38.82%
# Epoch 365 | train loss: 0.0229, acc: 99.75% | test loss: 3.7406, acc: 39.46%
# Epoch 366 | train loss: 0.0206, acc: 99.79% | test loss: 3.7425, acc: 38.95%
# Epoch 367 | train loss: 0.0233, acc: 99.70% | test loss: 3.7338, acc: 39.19%
# Epoch 368 | train loss: 0.0228, acc: 99.76% | test loss: 3.7152, acc: 39.59%
# Epoch 369 | train loss: 0.0226, acc: 99.73% | test loss: 3.7199, acc: 39.86%
# Epoch 370 | train loss: 0.0229, acc: 99.79% | test loss: 3.7298, acc: 39.32%
# Epoch 371 | train loss: 0.0206, acc: 99.80% | test loss: 3.7327, acc: 39.66%
# Epoch 372 | train loss: 0.0202, acc: 99.85% | test loss: 3.7069, acc: 39.69%
# Epoch 373 | train loss: 0.0212, acc: 99.79% | test loss: 3.7309, acc: 39.12%
# Epoch 374 | train loss: 0.0206, acc: 99.82% | test loss: 3.7091, acc: 38.89%
# Epoch 375 | train loss: 0.0189, acc: 99.88% | test loss: 3.6976, acc: 39.46%
# Epoch 376 | train loss: 0.0203, acc: 99.79% | test loss: 3.6940, acc: 39.93%
# Epoch 377 | train loss: 0.0192, acc: 99.88% | test loss: 3.6992, acc: 39.56%
# Epoch 378 | train loss: 0.0195, acc: 99.84% | test loss: 3.7194, acc: 39.29%
# Epoch 379 | train loss: 0.0206, acc: 99.80% | test loss: 3.7218, acc: 39.39%
# Epoch 380 | train loss: 0.0204, acc: 99.79% | test loss: 3.7219, acc: 39.22%
# Epoch 381 | train loss: 0.0192, acc: 99.86% | test loss: 3.7222, acc: 39.42%
# Epoch 382 | train loss: 0.0191, acc: 99.82% | test loss: 3.7197, acc: 38.95%
# Epoch 383 | train loss: 0.0210, acc: 99.81% | test loss: 3.7366, acc: 39.09%
# Epoch 384 | train loss: 0.0196, acc: 99.88% | test loss: 3.7132, acc: 39.42%
# Epoch 385 | train loss: 0.0195, acc: 99.82% | test loss: 3.7212, acc: 38.58%
# Epoch 386 | train loss: 0.0198, acc: 99.80% | test loss: 3.7064, acc: 39.66%
# Epoch 387 | train loss: 0.0200, acc: 99.81% | test loss: 3.6991, acc: 39.93%
# Epoch 388 | train loss: 0.0201, acc: 99.85% | test loss: 3.7189, acc: 39.52%
# Epoch 389 | train loss: 0.0206, acc: 99.83% | test loss: 3.7061, acc: 40.16%
# Epoch 390 | train loss: 0.0203, acc: 99.78% | test loss: 3.7262, acc: 39.15%
# Epoch 391 | train loss: 0.0191, acc: 99.82% | test loss: 3.7063, acc: 39.52%
# Epoch 392 | train loss: 0.0192, acc: 99.85% | test loss: 3.7050, acc: 39.49%
# Epoch 393 | train loss: 0.0169, acc: 99.90% | test loss: 3.7049, acc: 39.52%
# Epoch 394 | train loss: 0.0183, acc: 99.86% | test loss: 3.7097, acc: 39.52%
# Epoch 395 | train loss: 0.0194, acc: 99.82% | test loss: 3.7180, acc: 39.25%
# Epoch 396 | train loss: 0.0191, acc: 99.88% | test loss: 3.7198, acc: 40.06%
# Epoch 397 | train loss: 0.0188, acc: 99.82% | test loss: 3.7054, acc: 39.46%
# Epoch 398 | train loss: 0.0178, acc: 99.88% | test loss: 3.7059, acc: 39.52%
# Epoch 399 | train loss: 0.0180, acc: 99.84% | test loss: 3.7097, acc: 39.66%
# Epoch 400 | train loss: 0.0180, acc: 99.88% | test loss: 3.6942, acc: 39.93%
# Epoch 401 | train loss: 0.0185, acc: 99.85% | test loss: 3.6908, acc: 39.79%
# Epoch 402 | train loss: 0.0185, acc: 99.86% | test loss: 3.7058, acc: 39.32%
# Epoch 403 | train loss: 0.0187, acc: 99.85% | test loss: 3.7053, acc: 39.59%
# Epoch 404 | train loss: 0.0179, acc: 99.86% | test loss: 3.7075, acc: 40.26%
# Epoch 405 | train loss: 0.0181, acc: 99.86% | test loss: 3.7017, acc: 40.09%
# Epoch 406 | train loss: 0.0194, acc: 99.85% | test loss: 3.6926, acc: 40.06%
# Epoch 407 | train loss: 0.0166, acc: 99.91% | test loss: 3.7115, acc: 39.42%
# Epoch 408 | train loss: 0.0174, acc: 99.86% | test loss: 3.6919, acc: 39.29%
# Epoch 409 | train loss: 0.0172, acc: 99.89% | test loss: 3.6991, acc: 39.29%
# Epoch 410 | train loss: 0.0183, acc: 99.87% | test loss: 3.6987, acc: 39.52%
# Epoch 411 | train loss: 0.0170, acc: 99.90% | test loss: 3.7052, acc: 39.66%
# Epoch 412 | train loss: 0.0174, acc: 99.88% | test loss: 3.7150, acc: 39.25%
# Epoch 413 | train loss: 0.0181, acc: 99.85% | test loss: 3.7047, acc: 39.49%
# Epoch 414 | train loss: 0.0181, acc: 99.86% | test loss: 3.6997, acc: 39.39%
# Epoch 415 | train loss: 0.0168, acc: 99.91% | test loss: 3.6949, acc: 39.49%
# Epoch 416 | train loss: 0.0165, acc: 99.91% | test loss: 3.6951, acc: 39.59%
# Epoch 417 | train loss: 0.0165, acc: 99.89% | test loss: 3.6977, acc: 39.69%
# Epoch 418 | train loss: 0.0176, acc: 99.90% | test loss: 3.6874, acc: 39.66%
# Epoch 419 | train loss: 0.0170, acc: 99.89% | test loss: 3.6718, acc: 40.19%
# Epoch 420 | train loss: 0.0173, acc: 99.89% | test loss: 3.6924, acc: 39.86%
# Epoch 421 | train loss: 0.0176, acc: 99.87% | test loss: 3.6939, acc: 39.62%
# Epoch 422 | train loss: 0.0165, acc: 99.93% | test loss: 3.6891, acc: 39.86%
# Epoch 423 | train loss: 0.0168, acc: 99.89% | test loss: 3.6982, acc: 39.22%
# Epoch 424 | train loss: 0.0168, acc: 99.88% | test loss: 3.6937, acc: 39.93%
# Epoch 425 | train loss: 0.0174, acc: 99.85% | test loss: 3.6894, acc: 39.69%
# Epoch 426 | train loss: 0.0161, acc: 99.91% | test loss: 3.6861, acc: 39.36%
# Epoch 427 | train loss: 0.0176, acc: 99.91% | test loss: 3.6887, acc: 39.76%
# Epoch 428 | train loss: 0.0164, acc: 99.88% | test loss: 3.6859, acc: 39.79%
# Epoch 429 | train loss: 0.0170, acc: 99.88% | test loss: 3.6948, acc: 40.06%
# Epoch 430 | train loss: 0.0164, acc: 99.91% | test loss: 3.7021, acc: 39.79%
# Epoch 431 | train loss: 0.0175, acc: 99.89% | test loss: 3.7005, acc: 39.79%
# Epoch 432 | train loss: 0.0172, acc: 99.88% | test loss: 3.7067, acc: 39.86%
# Epoch 433 | train loss: 0.0169, acc: 99.86% | test loss: 3.7041, acc: 39.39%
# Epoch 434 | train loss: 0.0166, acc: 99.88% | test loss: 3.6841, acc: 40.03%
# Epoch 435 | train loss: 0.0177, acc: 99.85% | test loss: 3.6917, acc: 39.72%
# Epoch 436 | train loss: 0.0163, acc: 99.86% | test loss: 3.6896, acc: 39.72%
# Epoch 437 | train loss: 0.0173, acc: 99.86% | test loss: 3.6825, acc: 40.06%
# Epoch 438 | train loss: 0.0160, acc: 99.91% | test loss: 3.6793, acc: 39.89%
# Epoch 439 | train loss: 0.0175, acc: 99.89% | test loss: 3.6839, acc: 39.89%
# Epoch 440 | train loss: 0.0172, acc: 99.85% | test loss: 3.6810, acc: 39.76%
# Epoch 441 | train loss: 0.0163, acc: 99.91% | test loss: 3.6833, acc: 40.09%
# Epoch 442 | train loss: 0.0160, acc: 99.93% | test loss: 3.6875, acc: 40.03%
# Epoch 443 | train loss: 0.0161, acc: 99.89% | test loss: 3.6794, acc: 40.13%
# Epoch 444 | train loss: 0.0177, acc: 99.80% | test loss: 3.6813, acc: 39.72%
# Epoch 445 | train loss: 0.0163, acc: 99.89% | test loss: 3.6887, acc: 39.46%
# Epoch 446 | train loss: 0.0171, acc: 99.86% | test loss: 3.6801, acc: 39.93%
# Epoch 447 | train loss: 0.0160, acc: 99.91% | test loss: 3.6808, acc: 39.86%
# Epoch 448 | train loss: 0.0162, acc: 99.90% | test loss: 3.6779, acc: 39.99%
# Epoch 449 | train loss: 0.0157, acc: 99.94% | test loss: 3.6781, acc: 40.19%
# Epoch 450 | train loss: 0.0160, acc: 99.87% | test loss: 3.6794, acc: 40.03%
# Epoch 451 | train loss: 0.0172, acc: 99.82% | test loss: 3.6821, acc: 40.09%
# Epoch 452 | train loss: 0.0168, acc: 99.86% | test loss: 3.6863, acc: 40.09%
# Epoch 453 | train loss: 0.0162, acc: 99.86% | test loss: 3.6869, acc: 39.72%
# Epoch 454 | train loss: 0.0158, acc: 99.87% | test loss: 3.6870, acc: 39.79%
# Epoch 455 | train loss: 0.0164, acc: 99.88% | test loss: 3.6868, acc: 39.79%
# Epoch 456 | train loss: 0.0163, acc: 99.86% | test loss: 3.6853, acc: 40.09%
# Epoch 457 | train loss: 0.0162, acc: 99.87% | test loss: 3.6823, acc: 39.86%
# Epoch 458 | train loss: 0.0159, acc: 99.88% | test loss: 3.6795, acc: 39.79%
# Epoch 459 | train loss: 0.0160, acc: 99.88% | test loss: 3.6812, acc: 39.66%
# Epoch 460 | train loss: 0.0158, acc: 99.89% | test loss: 3.6794, acc: 39.99%
# Epoch 461 | train loss: 0.0157, acc: 99.89% | test loss: 3.6807, acc: 39.93%
# Epoch 462 | train loss: 0.0157, acc: 99.93% | test loss: 3.6777, acc: 39.72%
# Epoch 463 | train loss: 0.0151, acc: 99.90% | test loss: 3.6794, acc: 39.89%
# Epoch 464 | train loss: 0.0164, acc: 99.88% | test loss: 3.6796, acc: 40.13%
# Epoch 465 | train loss: 0.0160, acc: 99.86% | test loss: 3.6786, acc: 39.99%
# Epoch 466 | train loss: 0.0146, acc: 99.93% | test loss: 3.6775, acc: 39.93%
# Epoch 467 | train loss: 0.0163, acc: 99.91% | test loss: 3.6786, acc: 39.99%
# Epoch 468 | train loss: 0.0155, acc: 99.92% | test loss: 3.6776, acc: 39.89%
# Epoch 469 | train loss: 0.0159, acc: 99.88% | test loss: 3.6773, acc: 40.03%
# Epoch 470 | train loss: 0.0160, acc: 99.91% | test loss: 3.6779, acc: 40.03%
# Epoch 471 | train loss: 0.0151, acc: 99.93% | test loss: 3.6793, acc: 40.13%
# Epoch 472 | train loss: 0.0166, acc: 99.89% | test loss: 3.6797, acc: 39.99%
# Epoch 473 | train loss: 0.0154, acc: 99.93% | test loss: 3.6788, acc: 39.93%
# Epoch 474 | train loss: 0.0154, acc: 99.91% | test loss: 3.6786, acc: 39.99%
# Epoch 475 | train loss: 0.0169, acc: 99.85% | test loss: 3.6793, acc: 39.93%
# Epoch 476 | train loss: 0.0149, acc: 99.91% | test loss: 3.6792, acc: 40.03%
# Epoch 477 | train loss: 0.0162, acc: 99.86% | test loss: 3.6780, acc: 40.13%
# Epoch 478 | train loss: 0.0157, acc: 99.84% | test loss: 3.6764, acc: 40.06%
# Epoch 479 | train loss: 0.0168, acc: 99.88% | test loss: 3.6770, acc: 40.03%
# Epoch 480 | train loss: 0.0157, acc: 99.91% | test loss: 3.6761, acc: 40.09%
# Epoch 481 | train loss: 0.0163, acc: 99.91% | test loss: 3.6770, acc: 40.06%
# Epoch 482 | train loss: 0.0147, acc: 99.92% | test loss: 3.6774, acc: 40.19%
# Epoch 483 | train loss: 0.0156, acc: 99.92% | test loss: 3.6769, acc: 40.19%
# Epoch 484 | train loss: 0.0158, acc: 99.91% | test loss: 3.6767, acc: 40.16%
# Epoch 485 | train loss: 0.0160, acc: 99.89% | test loss: 3.6766, acc: 40.16%
# Epoch 486 | train loss: 0.0148, acc: 99.94% | test loss: 3.6769, acc: 40.13%
# Epoch 487 | train loss: 0.0155, acc: 99.92% | test loss: 3.6766, acc: 40.19%
# Epoch 488 | train loss: 0.0158, acc: 99.90% | test loss: 3.6768, acc: 40.13%
# Epoch 489 | train loss: 0.0147, acc: 99.91% | test loss: 3.6765, acc: 40.19%
# Epoch 490 | train loss: 0.0162, acc: 99.88% | test loss: 3.6765, acc: 40.23%
# Epoch 491 | train loss: 0.0147, acc: 99.93% | test loss: 3.6764, acc: 40.23%
# Epoch 492 | train loss: 0.0147, acc: 99.94% | test loss: 3.6761, acc: 40.23%
# Epoch 493 | train loss: 0.0153, acc: 99.94% | test loss: 3.6759, acc: 40.23%
# Epoch 494 | train loss: 0.0157, acc: 99.92% | test loss: 3.6759, acc: 40.23%
# Epoch 495 | train loss: 0.0152, acc: 99.92% | test loss: 3.6758, acc: 40.23%
# Epoch 496 | train loss: 0.0150, acc: 99.91% | test loss: 3.6759, acc: 40.23%
# Epoch 497 | train loss: 0.0157, acc: 99.91% | test loss: 3.6759, acc: 40.23%
# Epoch 498 | train loss: 0.0160, acc: 99.87% | test loss: 3.6759, acc: 40.23%
# Epoch 499 | train loss: 0.0158, acc: 99.90% | test loss: 3.6759, acc: 40.23%
# Epoch 500 | train loss: 0.0156, acc: 99.92% | test loss: 3.6759, acc: 40.23%
# BEST TEST ACC = 40.26% at epoch 404

# %%
from pathlib import Path
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm

@torch.no_grad()
def create_submission_from_features(head, test_feats, test_df, device, output_dir,
                                    batch_size=256):
    """
    Uses precomputed test_feats (N, D) and a trained head to create submission.csv.
    This exactly matches the sanity-checked evaluation.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    head = head.to(device).eval()

    N = test_feats.shape[0]
    assert N == len(test_df), f"Mismatch: test_feats={N}, test_df={len(test_df)}"

    # Dataset: (feats, idx) so we preserve order
    idx_tensor = torch.arange(N, dtype=torch.long)
    ds = TensorDataset(test_feats, idx_tensor)
    loader = DataLoader(ds, batch_size=batch_size, shuffle=False)

    pred_array = torch.zeros(N, dtype=torch.long)

    for feats_batch, idx in tqdm(loader, desc="Submission (features)"):
        feats_batch = feats_batch.to(device, non_blocking=True)
        logits = head(feats_batch)
        preds  = torch.argmax(logits, dim=1).cpu()
        pred_array[idx] = preds

    # optional sanity: check class distribution
    bincount = torch.bincount(pred_array)
    print("Prediction class counts:", bincount.tolist())

    submission = pd.DataFrame({
        "id": test_df["filename"].values,
        "class_id": pred_array.numpy(),
    })

    out_path = output_dir / "submission3.csv"
    submission.to_csv(out_path, index=False)
    print(f"\nSubmission written to: {out_path}")
    return submission

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# IMPORTANT: make sure you're using the trained/best head
linear_head.load_state_dict(torch.load("best_linear_head.pt", map_location=device))

submission = create_submission_from_features(
    head=linear_head,
    test_feats=test_feats,       # from your extract_features(...)
    test_df=test_df,
    device=device,
    output_dir=".",
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[62], line 4
#       1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       3 # IMPORTANT: make sure you're using the trained/best head
# ----> 4 linear_head.load_state_dict(torch.load("best_linear_head.pt", map_location=device))
#       6 submission = create_submission_from_features(
#       7     head=linear_head,
#       8     test_feats=test_feats,       # from your extract_features(...)
#    (...)     11     output_dir=".",
#      12 )
#
# File ~/code/environments/wejepa/lib/python3.12/site-packages/torch/nn/modules/module.py:2629, in Module.load_state_dict(self, state_dict, strict, assign)
#    2621         error_msgs.insert(
#    2622             0,
#    2623             "Missing key(s) in state_dict: {}. ".format(
#    2624                 ", ".join(f'"{k}"' for k in missing_keys)
#    2625             ),
#    2626         )
#    2628 if len(error_msgs) > 0:
# -> 2629     raise RuntimeError(
#    2630         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2631             self.__class__.__name__, "\n\t".join(error_msgs)
#    2632         )
#    2633     )
#    2634 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Sequential:
# 	size mismatch for 1.weight: copying a param with shape torch.Size([64, 2560]) from checkpoint, the shape in current model is torch.Size([397, 2560]).
# 	size mismatch for 1.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([397]).

# %%
submission

# %%
linear_head.eval()
with torch.no_grad():
    logits = linear_head(test_feats.to(device))
    preds  = torch.argmax(logits, dim=1).cpu()

correct = (preds == test_labels).sum().item()
acc = 100.0 * correct / len(test_labels)
print(f"Sanity check on stored test_feats: {acc:.2f}%")

# %%
from pathlib import Path
import pandas as pd
import torch
from tqdm import tqdm

@torch.no_grad()
def create_submission(encoder, head, test_loader, test_df, device, output_dir):
    """
    Runs encoder + head on test_loader and writes submission.csv,
    guaranteeing exact 1:1 alignment with test_df.
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    encoder = encoder.to(device).eval()
    head    = head.to(device).eval()

    N = len(test_df)
    pred_array = torch.zeros(N, dtype=torch.long)

    for batch in tqdm(test_loader, desc="Test inference (order-safe)"):
        # After the ImageDataset change, test batch = (images, labels, idx)
        images, _, idx = batch

        images = images.to(device, non_blocking=True)

        feats = encoder(images)
        if feats.dim() > 2:
            feats = feats.flatten(1)

        logits = head(feats)
        preds  = torch.argmax(logits, dim=1).cpu()

        # Place predictions into the correct positions
        pred_array[idx] = preds

    submission = pd.DataFrame({
        "id": test_df["filename"],      # matches the Kaggle-style column
        "class_id": pred_array.numpy(), # one prediction per row
    })

    out_path = output_dir / "submission.csv"
    submission.to_csv(out_path, index=False)
    print(f"\nSubmission written to: {out_path}")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder = model.encoder     # frozen encoder from your LinearProbeModel
head    = linear_head       # or model.classifier, whichever you trained

create_submission(
    encoder=encoder,
    head=head,
    test_loader=test_loader1,
    test_df=test_df,
    device=device,
    output_dir=".",
)
# Out:
# Test inference (order-safe): 100%|███████| 47/47 [00:03<00:00, 13.87it/s]
# Submission written to: submission.csv

# %%
 Saved checkpoint: /content/drive/MyDrive/dino-v1/dino-v1_latest_finetuned_18_big_data_texture.pt

# %%
# !ls /home/long/code/dl_project1/experiments/outputs/dino-v1/ -lrth
# Out:
# total 517M
# -rw-rw-r-- 1 long long 182M Dec  6 04:28 dino-v1_small_100.pt
# -rw-rw-r-- 1 long long 336M Dec  6 14:09 dino-v1_latest.pt

# %%
import torch
import pandas as pd
from tqdm import tqdm
import os


def create_submission(
    test_loader,
    head,                         # this is your linear_head
    output_path="submission.csv",
    device="cuda",
    encoder=None,                 # <-- NEW: optional encoder
):
    """
    Create submission.csv from test_loader and a trained linear head.

    Args:
        test_loader:
            - If encoder is not None:
                yields (images, filenames) or (images, labels, filenames)
                images: preprocessed tensors ready for encoder
            - If encoder is None:
                yields (features, filenames) or (features, labels, filenames)
                features: outputs of encoder (flattened)
        head: trained linear head; takes encoder features as input and outputs logits
        encoder: optional frozen encoder. If provided, we do:
                 feats = encoder(images); feats = feats.flatten(1) if needed
        output_path: where to save submission CSV
        device: 'cuda' or 'cpu'

    Returns:
        submission_df: DataFrame with 'id' and 'class_id'
        accuracy: test accuracy if labels are present, else None
    """

    device = device if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    head = head.to(device)
    head.eval()

    if encoder is not None:
        encoder = encoder.to(device)
        encoder.eval()
        for p in encoder.parameters():
            p.requires_grad = False

    # Check if dataloader is shuffled (common issue)
    if hasattr(test_loader, "sampler") and hasattr(test_loader.sampler, "shuffle"):
        if test_loader.sampler.shuffle:
            print("⚠️  WARNING: test_loader appears to be shuffled!")
            print("Make sure shuffle=False for submission.")

    all_predictions = []
    all_filenames = []
    correct = 0
    total = 0
    has_labels = False

    print("Generating predictions...")

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Inference"):
            # -------------------------
            # 1. Unpack batch
            # -------------------------
            if isinstance(batch, (list, tuple)):
                if len(batch) == 3:
                    x, labels, filenames = batch
                    has_labels = True
                elif len(batch) == 2:
                    x, second = batch
                    # Heuristic: tensor → labels, list/str → filenames
                    if isinstance(second, torch.Tensor):
                        x, labels = batch
                        filenames = None
                        has_labels = True
                    else:
                        x, filenames = batch
                        labels = None
                else:
                    raise ValueError(f"Unexpected batch length: {len(batch)}")
            else:
                # Dict style (not typical in your code, but kept for safety)
                x = batch["image"]
                filenames = batch.get("filename", batch.get("id"))
                labels = batch.get("label", batch.get("class_id"))
                if labels is not None:
                    has_labels = True

            # -------------------------
            # 2. Move to device
            # -------------------------
            if isinstance(x, torch.Tensor):
                x = x.to(device, non_blocking=True)

            if labels is not None and isinstance(labels, torch.Tensor):
                labels = labels.to(device, non_blocking=True)

            # -------------------------
            # 3. Forward: encoder (optional) + head
            # -------------------------
            with torch.cuda.amp.autocast():
                if encoder is not None:
                    feats = encoder(x)
                    if feats.dim() > 2:
                        feats = feats.flatten(1)
                    logits = head(feats)
                else:
                    # x is already features
                    logits = head(x)

            # -------------------------
            # 4. Predictions
            # -------------------------
            if logits.dim() == 2:
                _, preds = torch.max(logits, dim=1)
            else:  # already predictions
                preds = logits

            # accuracy if labels available
            if labels is not None:
                correct += (preds == labels).sum().item()
                total += labels.size(0)

            all_predictions.extend(preds.cpu().numpy())

            # -------------------------
            # 5. Filenames
            # -------------------------
            clean_names = []

            if filenames is None:
                # If you ever call this on a feature-loader without filenames,
                # you should instead pass filenames separately or avoid CSV here.
                raise ValueError(
                    "Filenames are None. For submission, test_loader must yield filenames."
                )

            if isinstance(filenames, torch.Tensor):
                for f in filenames.cpu().tolist():
                    clean_names.append(os.path.basename(str(f)))
            elif isinstance(filenames, list):
                for f in filenames:
                    clean_names.append(os.path.basename(str(f)))
            else:  # single string
                clean_names.append(os.path.basename(str(filenames)))

            all_filenames.extend(clean_names)

    # -------------------------
    # 6. Build submission
    # -------------------------

    import pdb
    pdb.set_trace()
    submission_df = pd.DataFrame({
        "id": all_filenames,
        "class_id": all_predictions,
    })

    # Deduplicate IDs if needed
    duplicates = submission_df[submission_df.duplicated(subset=["id"], keep=False)]
    if len(duplicates) > 0:
        print("\n⚠️  WARNING: Duplicate IDs found!")
        print(f"Number of duplicate entries: {len(duplicates)}")
        print("\nRemoving duplicates (keeping first occurrence)...")
        submission_df = submission_df.drop_duplicates(subset=["id"], keep="first")

    submission_df.to_csv(output_path, index=False)

    # -------------------------
    # 7. Accuracy if labels given
    # -------------------------
    accuracy = None
    if total > 0:
        accuracy = correct / total
        print(f"\n{'='*60}")
        print(f"TEST ACCURACY: {accuracy:.4f} ({accuracy*100:.2f}%)")
        print(f"Correct: {correct} / {total}")
        print(f"{'='*60}")

    # Summary
    print(f"\n{'='*60}")
    print(f"✓ Submission saved to: {output_path}")
    print(f"{'='*60}")
    print(f"Total predictions: {len(submission_df)}")
    print(f"Unique classes predicted: {submission_df['class_id'].nunique()}")
    print(f"\nClass distribution (top 10):")
    print(submission_df["class_id"].value_counts().head(10))

    # Validate format
    print("\nValidating submission format...")
    assert list(submission_df.columns) == ["id", "class_id"], "Invalid columns!"
    assert submission_df["class_id"].min() >= 0, "Invalid class_id < 0"
    assert submission_df.isnull().sum().sum() == 0, "Missing values found!"
    print("✓ Submission format is valid!")

    return submission_df, accuracy

# %%
linear_head
# Out:
# Linear(in_features=512, out_features=100, bias=True)

# %%
len(test_loader1)
# Out:
# 141

# %%
# reload best head
linear_head.load_state_dict(torch.load("best_linear_head.pt"))

# test_loader_comp should yield (images, filenames) with shuffle=False
submission_df, _ = create_submission(
    test_loader=test_loader1,
    head=linear_head,
    encoder=encoder,                # the frozen encoder you used for features
    output_path="submission.csv",
    device="cuda:1",
)
# Out:
# Using device: cuda:1
# Generating predictions...
# Inference:   0%|                                                                                                | 0/141 [00:00<?, ?it/s]/tmp/ipykernel_703917/3071104241.py:103: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Inference: 100%|██████████████████████████████████████████████████████████████████████████████████████| 141/141 [00:12<00:00, 11.37it/s]
# > /tmp/ipykernel_703917/3071104241.py(157)create_submission()
#     155     import pdb
#     156     pdb.set_trace()
# --> 157     submission_df = pd.DataFrame({
#     158         "id": all_filenames,
#     159         "class_id": all_predictions,
# ipdb>  exit

# %%
submission_df, _ = create_submission(
    test_loader=,
    head=linear_head,     # no encoder
    encoder=None,
    output_path="submission.csv",
    device="cuda",
)
# Out:
#   Cell In[46], line 2
#     test_loader=,
#     ^
# SyntaxError: expected argument value expression

# %%
import torch
import pandas as pd
from tqdm import tqdm

def create_submission_from_feats(
    test_feats,
    head,
    filenames,
    output_path="submission.csv",
    device="cuda",
    batch_size=512,
):
    """
    Create submission.csv using precomputed test_feats and a trained linear head.

    Args:
        test_feats: Tensor of shape (N, D), features from frozen encoder
        head: trained linear head mapping D -> num_classes
        filenames: list/array of length N with image ids (e.g. test_df['filename'])
        output_path: where to save submission.csv
        device: 'cuda' or 'cpu'
        batch_size: inference batch size

    Returns:
        submission_df: DataFrame with columns ['id', 'class_id']
    """
    device = device if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    head = head.to(device)
    head.eval()

    N = test_feats.shape[0]
    assert N == len(filenames), f"Mismatch: {N} feats vs {len(filenames)} filenames"

    all_preds = []

    with torch.no_grad():
        for start in tqdm(range(0, N, batch_size), desc="Inference (features)"):
            end = min(start + batch_size, N)
            batch_feats = test_feats[start:end].to(device, non_blocking=True)

            with torch.cuda.amp.autocast():
                logits = head(batch_feats)

            preds = logits.argmax(dim=1)
            all_preds.append(preds.cpu())

    all_preds = torch.cat(all_preds, dim=0).numpy()
    assert len(all_preds) == N

    submission_df = pd.DataFrame({
        "id": filenames,
        "class_id": all_preds,
    })

    submission_df.to_csv(output_path, index=False)

    print(f"\nSaved submission to {output_path}")
    print(f"Total predictions: {len(submission_df)}")
    print(f"Unique classes predicted: {submission_df['class_id'].nunique()}")
    print("\nClass distribution (top 10):")
    print(submission_df["class_id"].value_counts().head(10))

    # basic sanity checks
    print("\nValidating submission format...")
    assert list(submission_df.columns) == ["id", "class_id"], "Invalid columns!"
    assert submission_df["class_id"].min() >= 0, "Invalid class_id < 0"
    assert submission_df.isnull().sum().sum() == 0, "Missing values found!"
    print("✓ Submission format is valid!")

    return submission_df

# %%
device
# Out:
# 'cuda:1'

# %%
# from earlier
test_feats, test_labels = extract_features(encoder, test_loader1, device)
# and
test_df = pd.read_csv(data_dir / 'test_labels_INTERNAL.csv')  # or test_images.csv for Kaggle
# Out:
# Extracting: 100%|█████████████████████████████████████████████████████████████████████████████████████| 141/141 [00:06<00:00, 21.93it/s]

# %%
# Load best head
linear_head.load_state_dict(torch.load("best_linear_head.pt"))

# Filenames in the same order as test_feats / test_loader1
filenames = test_df["filename"].tolist()   # or 'id' for Kaggle test csv

submission_df = create_submission_from_feats(
    test_feats=test_feats,
    head=linear_head,
    filenames=filenames,
    output_path="submission.csv",
    device="cuda",
)
# Out:
# Using device: cuda
# Inference (features):   0%|                                                                                      | 0/18 [00:00<?, ?it/s]/tmp/ipykernel_703917/3851796085.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Inference (features): 100%|█████████████████████████████████████████████████████████████████████████████| 18/18 [00:00<00:00, 76.50it/s]
# Saved submission to submission.csv
# Total predictions: 9000
# Unique classes predicted: 1
#
# Class distribution (top 10):
# class_id
# 0    9000
# Name: count, dtype: int64
#
# Validating submission format...
# ✓ Submission format is valid!

# %%
feat_dim = trainval_feats.shape[1]
num_classes = int(trainval_labels.max().item() + 1)

linear_head = nn.Linear(feat_dim, num_classes).to(device)

criterion = torch.nn.CrossEntropyLoss()

# 🔴 IMPORTANT: optimizer must use linear_head.parameters()
optimizer = torch.optim.AdamW(
    linear_head.parameters(),
    lr=1e-3,
    weight_decay=1e-4,
)

scaler = torch.cuda.amp.GradScaler()
# Out:
# /tmp/ipykernel_496601/4156479919.py:15: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()

# %%
def run_epoch_head(head, loader, train=True):
    if train:
        head.train()
    else:
        head.eval()

    running_loss = 0.0
    correct = 0
    total = 0

    for feats, labels in loader:
        feats = feats.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        if train:
            optimizer.zero_grad(set_to_none=True)

        with torch.cuda.amp.autocast():
            logits = head(feats)
            loss = criterion(logits, labels)

        if train:
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        running_loss += loss.item() * labels.size(0)
        _, preds = torch.max(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = running_loss / total
    acc = 100.0 * correct / total
    return avg_loss, acc

# %%
num_epochs = 50
best_test_acc = 0.0
best_epoch = 0

for epoch in range(1, num_epochs + 1):
    train_loss, train_acc = run_epoch_head(linear_head, trainval_feat_loader, train=True)
    test_loss, test_acc   = run_epoch_head(linear_head, test_feat_loader,   train=False)

    # if you still want scheduler:
    scheduler.step()

    if test_acc > best_test_acc:
        best_test_acc = test_acc
        best_epoch = epoch
        torch.save(linear_head.state_dict(), "best_linear_head.pt")

    print(
        f"Epoch {epoch:02d} | "
        f"train loss: {train_loss:.4f}, acc: {train_acc:.2f}% | "
        f"test loss: {test_loss:.4f}, acc: {test_acc:.2f}%"
    )
    with torch.no_grad():
        w_norm = linear_head.weight.norm().item()
        print("Head weight norm:", w_norm)


print(f"BEST TEST ACC = {best_test_acc:.2f}% at epoch {best_epoch}")
# Out:
# /tmp/ipykernel_496601/2854452322.py:18: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 01 | train loss: 5.3503, acc: 0.99% | test loss: 5.1610, acc: 1.97%
# Head weight norm: 8.72060489654541
# Epoch 02 | train loss: 5.0719, acc: 2.69% | test loss: 4.9822, acc: 4.48%
# Head weight norm: 9.860909461975098
# Epoch 03 | train loss: 4.9029, acc: 4.48% | test loss: 4.8600, acc: 5.80%
# Head weight norm: 11.409844398498535
# Epoch 04 | train loss: 4.7823, acc: 6.33% | test loss: 4.7703, acc: 6.23%
# Head weight norm: 13.110548973083496
# Epoch 05 | train loss: 4.6873, acc: 7.51% | test loss: 4.6988, acc: 7.11%
# Head weight norm: 14.873912811279297
# Epoch 06 | train loss: 4.6122, acc: 8.43% | test loss: 4.6392, acc: 7.71%
# Head weight norm: 16.646989822387695
# Epoch 07 | train loss: 4.5452, acc: 9.22% | test loss: 4.5899, acc: 8.69%
# Head weight norm: 18.419111251831055
# Epoch 08 | train loss: 4.4865, acc: 10.18% | test loss: 4.5480, acc: 8.86%
# Head weight norm: 20.18934440612793
# Epoch 09 | train loss: 4.4326, acc: 10.46% | test loss: 4.5092, acc: 8.91%
# Head weight norm: 21.93984603881836
# Epoch 10 | train loss: 4.3881, acc: 11.06% | test loss: 4.4745, acc: 9.40%
# Head weight norm: 23.679462432861328
# Epoch 11 | train loss: 4.3436, acc: 11.89% | test loss: 4.4431, acc: 9.84%
# Head weight norm: 25.393388748168945
# Epoch 12 | train loss: 4.3058, acc: 11.95% | test loss: 4.4167, acc: 9.24%
# Head weight norm: 27.1061954498291
# Epoch 13 | train loss: 4.2695, acc: 12.43% | test loss: 4.3910, acc: 10.22%
# Head weight norm: 28.801393508911133
# Epoch 14 | train loss: 4.2351, acc: 12.96% | test loss: 4.3671, acc: 10.66%
# Head weight norm: 30.482755661010742
# Epoch 15 | train loss: 4.2026, acc: 13.70% | test loss: 4.3464, acc: 10.61%
# Head weight norm: 32.143428802490234
# Epoch 16 | train loss: 4.1739, acc: 13.54% | test loss: 4.3276, acc: 10.88%
# Head weight norm: 33.79731750488281
# Epoch 17 | train loss: 4.1434, acc: 14.23% | test loss: 4.3086, acc: 10.28%
# Head weight norm: 35.44292449951172
# Epoch 18 | train loss: 4.1177, acc: 14.31% | test loss: 4.2911, acc: 11.48%
# Head weight norm: 37.06880569458008
# Epoch 19 | train loss: 4.0937, acc: 14.77% | test loss: 4.2754, acc: 10.83%
# Head weight norm: 38.690975189208984
# Epoch 20 | train loss: 4.0668, acc: 14.86% | test loss: 4.2593, acc: 11.32%
# Head weight norm: 40.30258560180664
# Epoch 21 | train loss: 4.0428, acc: 15.49% | test loss: 4.2453, acc: 11.21%
# Head weight norm: 41.90180587768555
# Epoch 22 | train loss: 4.0206, acc: 15.74% | test loss: 4.2323, acc: 11.10%
# Head weight norm: 43.49089431762695
# Epoch 23 | train loss: 3.9991, acc: 15.82% | test loss: 4.2202, acc: 11.43%
# Head weight norm: 45.08111572265625
# Epoch 24 | train loss: 3.9774, acc: 16.21% | test loss: 4.2073, acc: 11.26%
# Head weight norm: 46.6534423828125
# Epoch 25 | train loss: 3.9598, acc: 16.37% | test loss: 4.1989, acc: 11.37%
# Head weight norm: 48.21952438354492
# Epoch 26 | train loss: 3.9401, acc: 16.38% | test loss: 4.1851, acc: 11.76%
# Head weight norm: 49.77816390991211
# Epoch 27 | train loss: 3.9201, acc: 16.89% | test loss: 4.1759, acc: 11.37%
# Head weight norm: 51.324867248535156
# Epoch 28 | train loss: 3.9049, acc: 16.96% | test loss: 4.1658, acc: 11.97%
# Head weight norm: 52.88046646118164
# Epoch 29 | train loss: 3.8844, acc: 17.48% | test loss: 4.1557, acc: 11.59%
# Head weight norm: 54.427921295166016
# Epoch 30 | train loss: 3.8681, acc: 17.99% | test loss: 4.1454, acc: 12.08%
# Head weight norm: 55.95675277709961
# Epoch 31 | train loss: 3.8504, acc: 17.58% | test loss: 4.1399, acc: 11.65%
# Head weight norm: 57.48326110839844
# Epoch 32 | train loss: 3.8328, acc: 18.11% | test loss: 4.1295, acc: 11.97%
# Head weight norm: 59.0148811340332
# Epoch 33 | train loss: 3.8202, acc: 18.16% | test loss: 4.1234, acc: 11.65%
# Head weight norm: 60.53211212158203
# Epoch 34 | train loss: 3.8044, acc: 18.53% | test loss: 4.1158, acc: 12.36%
# Head weight norm: 62.04293441772461
# Epoch 35 | train loss: 3.7867, acc: 19.08% | test loss: 4.1078, acc: 12.19%
# Head weight norm: 63.551483154296875
# Epoch 36 | train loss: 3.7712, acc: 18.98% | test loss: 4.1010, acc: 11.76%
# Head weight norm: 65.05517578125
# Epoch 37 | train loss: 3.7589, acc: 19.18% | test loss: 4.0954, acc: 12.68%
# Head weight norm: 66.55420684814453
# Epoch 38 | train loss: 3.7446, acc: 19.30% | test loss: 4.0877, acc: 12.03%
# Head weight norm: 68.04964447021484
# Epoch 39 | train loss: 3.7298, acc: 19.35% | test loss: 4.0825, acc: 12.19%
# Head weight norm: 69.53722381591797
# Epoch 40 | train loss: 3.7168, acc: 19.93% | test loss: 4.0763, acc: 12.30%
# Head weight norm: 71.03103637695312
# Epoch 41 | train loss: 3.7045, acc: 20.20% | test loss: 4.0705, acc: 12.52%
# Head weight norm: 72.51756286621094
# Epoch 42 | train loss: 3.6910, acc: 20.49% | test loss: 4.0633, acc: 12.52%
# Head weight norm: 73.9970474243164
# Epoch 43 | train loss: 3.6800, acc: 20.27% | test loss: 4.0585, acc: 12.19%
# Head weight norm: 75.4604263305664
# Epoch 44 | train loss: 3.6667, acc: 20.26% | test loss: 4.0552, acc: 12.58%
# Head weight norm: 76.93228912353516
# Epoch 45 | train loss: 3.6537, acc: 20.99% | test loss: 4.0476, acc: 13.07%
# Head weight norm: 78.4097671508789
# Epoch 46 | train loss: 3.6426, acc: 20.91% | test loss: 4.0435, acc: 12.68%
# Head weight norm: 79.8798828125
# Epoch 47 | train loss: 3.6300, acc: 20.90% | test loss: 4.0392, acc: 12.79%
# Head weight norm: 81.34052276611328
# Epoch 48 | train loss: 3.6210, acc: 21.46% | test loss: 4.0320, acc: 13.01%
# Head weight norm: 82.79801940917969
# Epoch 49 | train loss: 3.6092, acc: 21.36% | test loss: 4.0302, acc: 13.45%
# Head weight norm: 84.24639129638672
# Epoch 50 | train loss: 3.5961, acc: 21.95% | test loss: 4.0244, acc: 13.07%
# Head weight norm: 85.70915985107422
# BEST TEST ACC = 13.45% at epoch 49

# %%
print("num classes (unique labels):", trainval_labels.unique().numel())
print("min label:", trainval_labels.min().item())
print("max label:", trainval_labels.max().item())
# Out:
# num classes (unique labels): 200
# min label: 0
# max label: 199
