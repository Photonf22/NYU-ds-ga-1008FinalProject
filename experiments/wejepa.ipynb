# %% [markdown]
# # Example based on our README.md
# 1. Dataset download
# 2. Prepare dataset
# 3. Pre-training
# 4. Fine-tuning
# 5. Different backbones

# %% [markdown]
# ### Download the dataset

# %%
# using the cli

# download class dataset
#####  hugging face
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name tsbpp/fall2025_deeplearning --splits train
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name tsbpp/fall2025_deeplearning --splits 'train[:10]'
# download the class pretrain dataset raw data
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name tsbpp/fall2025_deeplearning --snapshot-download --splits train
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name gjuggler/extra-birds --snapshot-download --splits train
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name Sijuade/Cats-Dogs-Birds --snapshot-download --splits train

##### torchvision datasets
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name cifar100
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name voc2007
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name caltech101
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name caltech256
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name flowers102
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name coco_detection
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name coco_captions
#!python -m wejepa.datasets.download --dataset-root ./data --dataset-name imagenet --splits train

##### From URL
# download cub200 dataset
# !python -m wejepa.datasets.download --dataset-root ./data --dataset-name cub200 --splits train,test
# Out:
# Downloading CUB-200-2011 from https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz...
# Download complete!
# Extracting CUB-200-2011 dataset...
# Extraction complete!
# Generating CUB-200 train/val/test splits
# Split 'train,test' available under /home/long/code/dl_project1/experiments/data

# %% [markdown]
# ### Inspect and Prepare Dataset

# %%
# prepare raw images into huggingface dataset format (not needed with the current dataset structure)
# !python -m wejepa.datasets.prepare_images --input-dir ./data/tsbpp_fall2025_deeplearning --output-dir ./data/tsbpp___fall2025_deeplearning

# %% [markdown]
# ### Pre-training the model

# %%
# Using the cli

# Clear
# !export PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# Train using default cifar100 config + custom ViT backbone
# !python -m wejepa.train.pretrain --print-config     # print only
# !python -m wejepa.train.pretrain                    # train

# FIXME: bug when using .arrow files, the file path is not correctly set, workaround is to rename the arrow file
#   cp fall2025_deeplearning-train.arrow tsbpp___fall2025_deeplearning-train.arrow

# print where --config searches for config files
# !python -m wejepa.train.pretrain --config hf224_config.json

#!PYTHONWARNINGS="ignore::RuntimeWarning" python -m wejepa.train.pretrain --config configs/pretrain_devel_tsbpp_224.json
#!PYTHONWARNINGS="ignore::RuntimeWarning" python -m wejepa.train.pretrain --config configs/pretrain_vit_b_16_tsbpp_224.json
#!PYTHONWARNINGS="ignore::RuntimeWarning" python -m wejepa.train.pretrain --config configs/pretrain_convnext_small_tsbpp_224.json
#!PYTHONWARNINGS="ignore::RuntimeWarning" CUDA_VISIBLE_DEVICES=1,2,3 python -m wejepa.train.pretrain --config configs/pretrain_swin_s_tsbpp_224.json
#!PYTHONWARNINGS="ignore::RuntimeWarning" CUDA_VISIBLE_DEVICES=1,2,3 python -m wejepa.train.pretrain --config configs/pretrain_vit_b_16_devel_224.json

# !PYTHONWARNINGS="ignore::RuntimeWarning" CUDA_VISIBLE_DEVICES=0, python -m wejepa.train.pretrain --resume-checkpoint outputs/vit_b_16/2025_11_30/ijepa_epoch_0068.pt/ --config configs/domain_adaption_vit_b_16_cub200.json
# Out:
# Model has 70,881,792 trainable parameters.
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.22it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0001.pt
# Epoch 1/300 | loss=0.1490
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0002.pt
# Epoch 2/300 | loss=0.1145
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0003.pt
# Epoch 3/300 | loss=0.1047
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0004.pt
# Epoch 4/300 | loss=0.0968
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0005.pt
# Epoch 5/300 | loss=0.0908
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0006.pt
# Epoch 6/300 | loss=0.0877
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0007.pt
# Epoch 7/300 | loss=0.0863
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0008.pt
# Epoch 8/300 | loss=0.0816
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0009.pt
# Epoch 9/300 | loss=0.0777
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0010.pt
# Epoch 10/300 | loss=0.0748
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0011.pt
# Epoch 11/300 | loss=0.0745
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0012.pt
# Epoch 12/300 | loss=0.0760
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0013.pt
# Epoch 13/300 | loss=0.0826
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0014.pt
# Epoch 14/300 | loss=0.0871
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.36it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0015.pt
# Epoch 15/300 | loss=0.0916
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0016.pt
# Epoch 16/300 | loss=0.0922
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0017.pt
# Epoch 17/300 | loss=0.0961
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0018.pt
# Epoch 18/300 | loss=0.0986
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0019.pt
# Epoch 19/300 | loss=0.1012
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0020.pt
# Epoch 20/300 | loss=0.0985
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0021.pt
# Epoch 21/300 | loss=0.1051
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0022.pt
# Epoch 22/300 | loss=0.1067
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0023.pt
# Epoch 23/300 | loss=0.1089
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0024.pt
# Epoch 24/300 | loss=0.1096
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0025.pt
# Epoch 25/300 | loss=0.1124
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0026.pt
# Epoch 26/300 | loss=0.1141
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0027.pt
# Epoch 27/300 | loss=0.1135
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0028.pt
# Epoch 28/300 | loss=0.1152
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0029.pt
# Epoch 29/300 | loss=0.1158
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0030.pt
# Epoch 30/300 | loss=0.1185
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0031.pt
# Epoch 31/300 | loss=0.1170
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0032.pt
# Epoch 32/300 | loss=0.1182
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0033.pt
# Epoch 33/300 | loss=0.1205
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0034.pt
# Epoch 34/300 | loss=0.1183
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0035.pt
# Epoch 35/300 | loss=0.1153
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0036.pt
# Epoch 36/300 | loss=0.1158
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0037.pt
# Epoch 37/300 | loss=0.1172
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.25it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0038.pt
# Epoch 38/300 | loss=0.1167
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0039.pt
# Epoch 39/300 | loss=0.1155
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0040.pt
# Epoch 40/300 | loss=0.1170
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0041.pt
# Epoch 41/300 | loss=0.1135
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0042.pt
# Epoch 42/300 | loss=0.1121
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0043.pt
# Epoch 43/300 | loss=0.1145
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0044.pt
# Epoch 44/300 | loss=0.1155
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0045.pt
# Epoch 45/300 | loss=0.1127
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0046.pt
# Epoch 46/300 | loss=0.1172
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0047.pt
# Epoch 47/300 | loss=0.1175
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0048.pt
# Epoch 48/300 | loss=0.1162
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0049.pt
# Epoch 49/300 | loss=0.1172
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0050.pt
# Epoch 50/300 | loss=0.1179
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0051.pt
# Epoch 51/300 | loss=0.1143
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0052.pt
# Epoch 52/300 | loss=0.1173
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0053.pt
# Epoch 53/300 | loss=0.1151
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0054.pt
# Epoch 54/300 | loss=0.1147
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.25it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0055.pt
# Epoch 55/300 | loss=0.1127
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0056.pt
# Epoch 56/300 | loss=0.1124
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0057.pt
# Epoch 57/300 | loss=0.1129
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0058.pt
# Epoch 58/300 | loss=0.1133
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.36it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0059.pt
# Epoch 59/300 | loss=0.1149
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0060.pt
# Epoch 60/300 | loss=0.1140
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0061.pt
# Epoch 61/300 | loss=0.1151
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0062.pt
# Epoch 62/300 | loss=0.1137
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.38it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0063.pt
# Epoch 63/300 | loss=0.1128
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0064.pt
# Epoch 64/300 | loss=0.1124
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0065.pt
# Epoch 65/300 | loss=0.1117
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0066.pt
# Epoch 66/300 | loss=0.1131
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0067.pt
# Epoch 67/300 | loss=0.1126
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0068.pt
# Epoch 68/300 | loss=0.1117
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0069.pt
# Epoch 69/300 | loss=0.1133
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0070.pt
# Epoch 70/300 | loss=0.1119
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0071.pt
# Epoch 71/300 | loss=0.1108
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0072.pt
# Epoch 72/300 | loss=0.1091
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.24it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0073.pt
# Epoch 73/300 | loss=0.1088
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0074.pt
# Epoch 74/300 | loss=0.1081
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0075.pt
# Epoch 75/300 | loss=0.1074
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.25it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0076.pt
# Epoch 76/300 | loss=0.1087
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0077.pt
# Epoch 77/300 | loss=0.1097
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0078.pt
# Epoch 78/300 | loss=0.1081
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0079.pt
# Epoch 79/300 | loss=0.1085
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0080.pt
# Epoch 80/300 | loss=0.1098
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0081.pt
# Epoch 81/300 | loss=0.1094
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0082.pt
# Epoch 82/300 | loss=0.1058
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0083.pt
# Epoch 83/300 | loss=0.1073
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0084.pt
# Epoch 84/300 | loss=0.1068
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0085.pt
# Epoch 85/300 | loss=0.1068
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0086.pt
# Epoch 86/300 | loss=0.1088
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0087.pt
# Epoch 87/300 | loss=0.1060
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0088.pt
# Epoch 88/300 | loss=0.1074
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0089.pt
# Epoch 89/300 | loss=0.1066
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0090.pt
# Epoch 90/300 | loss=0.1070
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0091.pt
# Epoch 91/300 | loss=0.1072
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0092.pt
# Epoch 92/300 | loss=0.1059
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.35it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0093.pt
# Epoch 93/300 | loss=0.1067
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.25it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0094.pt
# Epoch 94/300 | loss=0.1053
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0095.pt
# Epoch 95/300 | loss=0.1077
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0096.pt
# Epoch 96/300 | loss=0.1041
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0097.pt
# Epoch 97/300 | loss=0.1044
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0098.pt
# Epoch 98/300 | loss=0.1065
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.31it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0099.pt
# Epoch 99/300 | loss=0.1049
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.26it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0100.pt
# Epoch 100/300 | loss=0.1044
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0101.pt
# Epoch 101/300 | loss=0.1015
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0102.pt
# Epoch 102/300 | loss=0.1007
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0103.pt
# Epoch 103/300 | loss=0.1025
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.36it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0104.pt
# Epoch 104/300 | loss=0.1022
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0105.pt
# Epoch 105/300 | loss=0.1023
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0106.pt
# Epoch 106/300 | loss=0.0998
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0107.pt
# Epoch 107/300 | loss=0.0997
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0108.pt
# Epoch 108/300 | loss=0.1000
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0109.pt
# Epoch 109/300 | loss=0.0983
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.27it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0110.pt
# Epoch 110/300 | loss=0.0965
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0111.pt
# Epoch 111/300 | loss=0.0991
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0112.pt
# Epoch 112/300 | loss=0.0990
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0113.pt
# Epoch 113/300 | loss=0.0994
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.36it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_
/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0281.pt
# Epoch 281/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0282.pt
# Epoch 282/300 | loss=0.0511
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.25it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0283.pt
# Epoch 283/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.38it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0284.pt
# Epoch 284/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0285.pt
# Epoch 285/300 | loss=0.0505
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0286.pt
# Epoch 286/300 | loss=0.0503
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.37it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0287.pt
# Epoch 287/300 | loss=0.0511
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0288.pt
# Epoch 288/300 | loss=0.0497
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0289.pt
# Epoch 289/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0290.pt
# Epoch 290/300 | loss=0.0511
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.34it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0291.pt
# Epoch 291/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.32it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0292.pt
# Epoch 292/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0293.pt
# Epoch 293/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.39it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0294.pt
# Epoch 294/300 | loss=0.0514
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.29it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0295.pt
# Epoch 295/300 | loss=0.0500
# Training: 100%|█████████████████████████████████| 64/64 [00:28<00:00,  2.28it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0296.pt
# Epoch 296/300 | loss=0.0501
# Training: 100%|█████████████████████████████████| 64/64 [00:26<00:00,  2.40it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0297.pt
# Epoch 297/300 | loss=0.0512
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.30it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0298.pt
# Epoch 298/300 | loss=0.0508
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0299.pt
# Epoch 299/300 | loss=0.0512
# Training: 100%|█████████████████████████████████| 64/64 [00:27<00:00,  2.33it/s]
# Epoch completed.
# Saved checkpoint to outputs/vit_b_16/domain_adaption/ijepa_epoch_0300.pt
# Epoch 300/300 | loss=0.0506

# %%
# programmatically
from wejepa import default_config, launch_pretraining
cfg = default_config()
launch_pretraining(cfg)

# %% [markdown]
# ### Fine tuning the model

# %%
# using the cli
# !CUDA_VISIBLE_DEVICES=0 python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/domain_adaption/ijepa_epoch_0300.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-3 \
    --num-classes 200 \
    --config configs/finetune_vit_b_16_cub200_224.json
# Out:
# [Linear probe] Epoch 1/20 | loss=5.5793 | train_acc=0.007 | val_acc=0.009
# [Linear probe] Epoch 2/20 | loss=5.3701 | train_acc=0.013 | val_acc=0.012
# [Linear probe] Epoch 3/20 | loss=5.3185 | train_acc=0.011 | val_acc=0.012
# [Linear probe] Epoch 4/20 | loss=5.2710 | train_acc=0.015 | val_acc=0.010
# [Linear probe] Epoch 5/20 | loss=5.2821 | train_acc=0.016 | val_acc=0.010
# [Linear probe] Epoch 6/20 | loss=5.2607 | train_acc=0.016 | val_acc=0.013
# [Linear probe] Epoch 7/20 | loss=5.2597 | train_acc=0.014 | val_acc=0.015
# [Linear probe] Epoch 8/20 | loss=5.2538 | train_acc=0.014 | val_acc=0.013
# [Linear probe] Epoch 9/20 | loss=5.2138 | train_acc=0.016 | val_acc=0.014
# [Linear probe] Epoch 10/20 | loss=5.2034 | train_acc=0.018 | val_acc=0.011
# [Linear probe] Epoch 11/20 | loss=5.2017 | train_acc=0.021 | val_acc=0.013
# [Linear probe] Epoch 12/20 | loss=5.1967 | train_acc=0.019 | val_acc=0.016
# [Linear probe] Epoch 13/20 | loss=5.2055 | train_acc=0.020 | val_acc=0.013
# [Linear probe] Epoch 14/20 | loss=5.1827 | train_acc=0.018 | val_acc=0.014
# [Linear probe] Epoch 15/20 | loss=5.1978 | train_acc=0.019 | val_acc=0.019
# [Linear probe] Epoch 16/20 | loss=5.1652 | train_acc=0.021 | val_acc=0.013
# [Linear probe] Epoch 17/20 | loss=5.1718 | train_acc=0.021 | val_acc=0.016
# [Linear probe] Epoch 18/20 | loss=5.1763 | train_acc=0.022 | val_acc=0.012
# [Linear probe] Epoch 19/20 | loss=5.1538 | train_acc=0.022 | val_acc=0.015
# [Linear probe] Epoch 20/20 | loss=5.1629 | train_acc=0.022 | val_acc=0.016

# %%
# !python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/ijepa_epoch_0025.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-4 \
    --num-classes 200 \
    --config configs/finetune_vit_b_16_bypass_cub200_224.json
# Out:
# [Linear probe] Epoch 1/20 | loss=5.2969 | train_acc=0.007 | val_acc=0.013
# [Linear probe] Epoch 2/20 | loss=5.1500 | train_acc=0.015 | val_acc=0.020
# [Linear probe] Epoch 3/20 | loss=5.0920 | train_acc=0.018 | val_acc=0.015
# [Linear probe] Epoch 4/20 | loss=5.0558 | train_acc=0.024 | val_acc=0.019
# [Linear probe] Epoch 5/20 | loss=5.0325 | train_acc=0.024 | val_acc=0.019
# [Linear probe] Epoch 6/20 | loss=5.0094 | train_acc=0.026 | val_acc=0.021
# [Linear probe] Epoch 7/20 | loss=4.9930 | train_acc=0.027 | val_acc=0.021
# [Linear probe] Epoch 8/20 | loss=4.9780 | train_acc=0.026 | val_acc=0.019
# [Linear probe] Epoch 9/20 | loss=4.9636 | train_acc=0.030 | val_acc=0.024
# [Linear probe] Epoch 10/20 | loss=4.9496 | train_acc=0.031 | val_acc=0.026
# [Linear probe] Epoch 11/20 | loss=4.9411 | train_acc=0.032 | val_acc=0.021
# [Linear probe] Epoch 12/20 | loss=4.9260 | train_acc=0.031 | val_acc=0.026
# [Linear probe] Epoch 13/20 | loss=4.9186 | train_acc=0.031 | val_acc=0.024
# ^C

# %%
# !python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/ijepa_epoch_0025.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-4 \
    --num-classes 200 \
    --config configs/finetune_vit_b_16_bypass_jepa_cub200_224.json

# %%
# !python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/ijepa_epoch_0025.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-4 \
    --num-classes 200 \
    --config configs/finetune_pretrained_vit_b_16_cub200_224.json
# Out:
# [Linear probe] Epoch 1/20 | loss=4.8953 | train_acc=0.071 | val_acc=0.172
# [Linear probe] Epoch 2/20 | loss=3.9557 | train_acc=0.271 | val_acc=0.336
# [Linear probe] Epoch 3/20 | loss=3.2911 | train_acc=0.421 | val_acc=0.419
# [Linear probe] Epoch 4/20 | loss=2.8250 | train_acc=0.520 | val_acc=0.488
# [Linear probe] Epoch 5/20 | loss=2.4839 | train_acc=0.575 | val_acc=0.516
# [Linear probe] Epoch 6/20 | loss=2.2262 | train_acc=0.615 | val_acc=0.537
# ^C

# %%
# !python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/ijepa_epoch_0025.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-4 \
    --num-classes 200 \
    --config configs/finetune_pretrained__no_bypass_vit_b_16_cub200_224.json
# Out:
# [Linear probe] Epoch 1/20 | loss=5.2838 | train_acc=0.013 | val_acc=0.017

# %%
# !python -m wejepa.train.finetune \
    --checkpoint outputs/vit_b_16/ijepa_epoch_0026.pt \
    --epochs 20 \
    --batch-size 256 \
    --lr 3e-4 \
    --num-classes 200 \
    --config configs/finetune_pretrained__no_bypass_vit_b_16_jepa_cub200_224.json

# %%
# programmatically
from wejepa.train import FinetuneConfig, train_linear_probe

ft_cfg = FinetuneConfig(
    checkpoint_path="outputs/ijepa/ijepa_epoch_0005.pt",
    epochs=5,
    batch_size=128,
    learning_rate=1e-3,
)
train_linear_probe(ft_cfg)

# %% [markdown]
# ### Different Backbones

# %%
import json
import torch
from copy import deepcopy
from pathlib import Path

from wejepa.backbones import adapt_config_for_backbone, available_backbones
from wejepa.config import IJepaConfig
from wejepa import default_config, launch_pretraining, IJEPA_base

print("Registered backbones: ")
for backbone in available_backbones():
    print(f"- {backbone}")

candidates = ["vit_b_16", "swin_t", "convnext_tiny"]
for backbone in candidates:
    print(f"\nPretraining with backbone: {backbone}")

for backbone in available_backbones():
    cfg = adapt_config_for_backbone(default_config(), backbone)
    print(f"\nBackbone: {backbone}")
    print(f"Image size: {cfg.model.img_size} | Patch size: {cfg.model.patch_size}")

    model = IJEPA_base(
        img_size=cfg.model.img_size,
        patch_size=cfg.model.patch_size,
        in_chans=cfg.model.in_chans,
        embed_dim=cfg.model.embed_dim,
        enc_depth=cfg.model.enc_depth,
        pred_depth=cfg.model.pred_depth,
        num_heads=cfg.model.num_heads,
        backbone=cfg.model.classification_backbone,
        pretrained=cfg.model.classification_pretrained,
    )

    print(f"Total trainable params: {model.count_trainable_parameters() / 1e6:.2f}M")
    print(f"Student + predictor params: {model.count_parameters() / 1e6:.2f}M")

    dummy = torch.randn(1, cfg.model.in_chans, cfg.model.img_size, cfg.model.img_size)
    preds, targets = model(dummy)
    print(f"Pred shape: {tuple(preds.shape)} | Target shape: {tuple(targets.shape)}")
    print(json.dumps(cfg.to_dict(), indent=2))

    cfg.hardware.output_dir = f"./outputs/ijepa/{backbone}"
    cfg_path = Path(f"configs/pretrain_{backbone}.json")
    cfg_path.parent.mkdir(parents=True, exist_ok=True)
    cfg_path.write_text(json.dumps(cfg.to_dict(), indent=2))
    print(f"Saved config for {backbone} at {cfg_path}")

    # launch_pretraining(cfg)
